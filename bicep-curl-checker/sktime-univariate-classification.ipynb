# %% [markdown]
# # Analysing Form using Sktime Univariate Classification

# %% [markdown]
# Author: Abid Mahdi, University of Southampton. 28/03/2022. am14g19@soton.ac.uk.
#
# Exploring classifiers to analyse univariate time series of the bicep curls dataset.
#
# ## TOC:
# 0. [Import Libraries & Setup Helper Functions](#0.-Import-Libraries-&-Setup)
# 1. [Setup Training & Testing Sets](#1.-Setup-Training-&-Testing-Sets)
# 2. [Train & Evaluate Models](#2.-Train-&-Evaluate-Models)
#     * [Using Elbow-Hip Angle](#Using-Elbow-Hip-Angle-(13,-11,-23))
#     * [Using Bicep Angle](#Using-Bicep-Angle-(11,-13,-15))
#     * [Using Hip Angle](#Using-Hip-Angle-(11,-23,-25))
# 3. [Choosing the Best Model](#3.-Choose-Best-Model)
#     * [Best for Elbow-Hip Angle](#Best-Classifier-for-Elbow-Hip-Angle)
#     * [Best for Bicep Angle](#Best-Classifier-for-Bicep-Angle)
#     * [Best for Hip Angle](#Best-Classifier-for-Hip-Angle)

# %% [markdown]
# # 0. Import Libraries & Setup

# %%
! pip install sktime

import sktime
from sktime.classification.all import TimeSeriesForestClassifier, KNeighborsTimeSeriesClassifier, ElasticEnsemble, ProximityForest
from sktime.classification.shapelet_based import ShapeletTransformClassifier
from sktime.classification.kernel_based import Arsenal
from sktime.classification.hybrid import HIVECOTEV1
from sktime.classification.dictionary_based import IndividualBOSS, BOSSEnsemble, WEASEL, MUSE
from sktime.contrib.vector_classifiers._rotation_forest import RotationForest

from sklearn.model_selection import train_test_split

import sklearn.metrics as metrics
from sklearn.metrics import accuracy_score, recall_score, precision_score ,f1_score
from sklearn.metrics import classification_report, ConfusionMatrixDisplay, confusion_matrix

import pickle
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: sktime in c:\users\abid5.000\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: deprecated>=1.2.13 in c:\users\abid5.000\anaconda3\lib\site-packages (from sktime) (1.2.13)
# Requirement already satisfied: pandas<1.5.0,>=1.1.0 in c:\users\abid5.000\anaconda3\lib\site-packages (from sktime) (1.2.4)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\abid5.000\anaconda3\lib\site-packages (from sktime) (0.12.2)
# Requirement already satisfied: numba>=0.53 in c:\users\abid5.000\anaconda3\lib\site-packages (from sktime) (0.53.1)
# Requirement already satisfied: scikit-learn>=0.24.0 in c:\users\abid5.000\anaconda3\lib\site-packages (from sktime) (0.24.1)
# Requirement already satisfied: numpy<1.22,>=1.21.0 in c:\users\abid5.000\anaconda3\lib\site-packages (from sktime) (1.21.5)
# Requirement already satisfied: scipy<1.8.0 in c:\users\abid5.000\anaconda3\lib\site-packages (from sktime) (1.6.2)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\abid5.000\anaconda3\lib\site-packages (from deprecated>=1.2.13->sktime) (1.12.1)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in c:\users\abid5.000\anaconda3\lib\site-packages (from numba>=0.53->sktime) (0.36.0)
# Requirement already satisfied: setuptools in c:\users\abid5.000\anaconda3\lib\site-packages (from numba>=0.53->sktime) (52.0.0.post20210125)
# Requirement already satisfied: pytz>=2017.3 in c:\users\abid5.000\anaconda3\lib\site-packages (from pandas<1.5.0,>=1.1.0->sktime) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\abid5.000\anaconda3\lib\site-packages (from pandas<1.5.0,>=1.1.0->sktime) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\abid5.000\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas<1.5.0,>=1.1.0->sktime) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\abid5.000\anaconda3\lib\site-packages (from scikit-learn>=0.24.0->sktime) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\abid5.000\anaconda3\lib\site-packages (from scikit-learn>=0.24.0->sktime) (1.0.1)
# Requirement already satisfied: patsy>=0.5 in c:\users\abid5.000\anaconda3\lib\site-packages (from statsmodels>=0.12.1->sktime) (0.5.1)

# %%
# Load
all_videos = pickle.load(open('all-bicep-curls.dump', 'rb'))

# %%
# Find the shortest and longest length video in terms of frame number
lengths = []

for video in all_videos:
    lengths.append(len(video[1]))
    
shortest_vid = min(lengths)
longest_vid = max(lengths)

# %%
# The list we want to convert has format: [{'frame': num, 'coordinates': {'x1'...'z33'}}]
def convert_list_to_df(list_to_convert):
    d = {'frame': []}
    for i in range(33):
        d['x' +  str(i)] = []
        d['y' +  str(i)] = []
        d['z' +  str(i)] = []
    
    for frame in list_to_convert:
        d['frame'].append(frame['frame'])
        for j in range(33):
            d['x' +  str(j)].append(frame['coordinates']['x' + str(j)])
            d['y' +  str(j)].append(frame['coordinates']['y' + str(j)])
            d['z' +  str(j)].append(frame['coordinates']['z' + str(j)])
    return d

# %%
# Get the angle between 3 keypoint's coordinates
# INPUT: frame (dictonary storing the coordinates of all the keypoints), the keypoint numbers (3 ints)
# OUTPUT: angle as float
def get_angle(frame, keypoint_1, keypoint_2, keypoint_3):
    a = np.array([frame['x'+str(keypoint_1)], frame['y'+str(keypoint_1)]]) # First
    b = np.array([frame['x'+str(keypoint_2)], frame['y'+str(keypoint_2)]]) # Mid
    c = np.array([frame['x'+str(keypoint_3)], frame['y'+str(keypoint_3)]]) # End
    
    ba = a - b
    bc = c - b

    cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
    angle = math.degrees(np.arccos(cosine_angle))
    
    if angle > 180.0:
        angle = 360 - angle
        
    return angle

# %%
# Change a column in a DataFrame to a Series
# Also makes all the series generated from videos the same length
# INPUT: Column name and DataFrame we want to extract in form {frame number: value at that frame number}
# OUTPUT: Pandas Series of the dictionary formed
def df_column_to_series(name, df):
    out_dict = {}

    largest_frame = 0
    
    for i in range(longest_vid):
        # If the video is shorther than the largest video, fill the values in the series with 0.0
        if i >= len(df):
            largest_frame += 1
            out_dict[largest_frame] = 0.0 
        else:
            out_dict[int(df.iloc[i]['frame'])-1] = df.iloc[i][name]
            largest_frame = int(df.iloc[i]['frame'])-1
    
    return pd.Series(out_dict)

# %% [markdown]
# In order for sktime univariate classification to work, we need the series to be the same length, but we have videos of different lengths. To account for this we make all the series the same length by zero-padding the end of the series to match the longest length video (the video with the most frames).

# %%
# Change the shape from: number of frames x features to: 1 x features length for sktime
# INPUT: The DataFrame we want to convert
# OUTPUT: The new converted DataFrame
def df_reshape(df):
    data = {}

    for col in df.columns:
        data[col] = []

    for col in df.columns:
        data[col].append(df_column_to_series(col, df))

    data.pop('frame')
    return pd.DataFrame(data)

# %% [markdown]
# # 1. Setup Training & Testing Sets

# %%
# Form the testing and training sets
X = []
y = []

for i in all_videos:
    X.append(i[1])
    y.append(i[0])

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

y_train = pd.Series(y_train)

# %% [markdown]
# ![landmarks.png](attachment:landmarks.png)

# %%
# Get data in the right form for the classifiers
X_train_df = pd.DataFrame()

for vid in X_train:
    df = pd.DataFrame(convert_list_to_df(vid)) 
    
    # Extract the useful angles
    df['elbow_hip_angle'] = df.apply(lambda row: get_angle(row, 23, 11, 13), axis=1)
    df['bicep_angle'] = df.apply(lambda row: get_angle(row, 15, 13, 11), axis=1)
    df['hip_angle'] = df.apply(lambda row: get_angle(row, 11, 23, 25), axis=1)
    
    X_train_df = X_train_df.append(df_reshape(df))

# %%
X_train_df
# Out:
#                                                   x0  \
# 0  0      0.451737
# 1      0.450623
# 2      0.45047...
# 0  0      0.424395
# 1      0.424313
# 2      0.42429...
# 0  0      0.552434
# 1      0.552468
# 2      0.55233...
# 0  0      0.436087
# 1      0.434971
# 2      0.43457...
# 0  0      0.404271
# 1      0.404261
# 2      0.40442...
# 0  0      0.433079
# 1      0.432823
# 2      0.43134...
# 0  0      0.403426
# 1      0.403433
# 2      0.40344...
# 0  0      0.417231
# 1      0.413327
# 2      0.41327...
# 0  0      0.436938
# 1      0.437132
# 2      0.43888...
# 0  0      0.413980
# 1      0.412879
# 2      0.41245...
# 0  0      0.393237
# 1      0.392632
# 2      0.39138...
# 0  0      0.454956
# 1      0.454911
# 2      0.45472...
# 0  0      0.445515
# 1      0.445548
# 2      0.44594...
# 0  0      0.491687
# 1      0.490186
# 2      0.48872...
# 0  0      0.451610
# 1      0.450410
# 2      0.44937...
# 0  0      0.352614
# 1      0.353499
# 2      0.35421...
# 0  0      0.475560
# 1      0.475630
# 2      0.47565...
# 0  0      0.425033
# 1      0.425063
# 2      0.42524...
# 0  0      0.359016
# 1      0.357956
# 2      0.35747...
# 0  0      0.426760
# 1      0.426862
# 2      0.42686...
# 0  0      0.483980
# 1      0.485607
# 2      0.48629...
# 0  0      0.388822
# 1      0.388392
# 2      0.38691...
# 0  0      0.537960
# 1      0.537358
# 2      0.53608...
# 0  0      0.418077
# 1      0.417671
# 2      0.41757...
# 0  0      0.408967
# 1      0.408666
# 2      0.40832...
# 0  0      0.540164
# 1      0.539954
# 2      0.53941...
# 0  0      0.437312
# 1      0.437730
# 2      0.43822...
# 0  0      0.434762
# 1      0.434648
# 2      0.43520...
# 0  0      0.422905
# 1      0.420900
# 2      0.41920...
# 0  0      0.448112
# 1      0.446502
# 2      0.44498...
# 0  0      0.381702
# 1      0.379083
# 2      0.37787...
# 0  0      0.407190
# 1      0.405906
# 2      0.40557...
# 0  0      0.367538
# 1      0.367471
# 2      0.36722...
# 2      0.11432...
# 0  0      0.177007
# 1      0.176980
# 2      0.17696...
# 0  0      0.137092
# 1      0.136857
# 2      0.13579...
# 0  0      0.192191
# 1      0.192049
# 2      0.19295...
# 0  0      0.179291
# 1      0.179504
# 2      0.17951...
# 0  0      0.257076
# 1      0.257339
# 2      0.25811...
# 0  0      0.156202
# 1      0.156236
# 2      0.15589...
# 0  0      0.187143
# 1      0.188640
# 2      0.19024...
# 0  0      0.205736
# 1      0.207816
# 2      0.20947...
# 0  0      0.127890
# 1      0.125580
# 2      0.12474...
# 0  0      0.133957
# 1      0.132987
# 2      0.13205...
# 0  0      0.183862
# 1      0.183895
# 2      0.18394...
# 0  0      0.116628
# 1      0.116405
# 2      0.11625...
# 0  0      0.203679
# 1      0.205972
# 2      0.20723...
# 0  0      0.224492
# 1      0.224567
# 2      0.22447...
# 0  0      0.132928
# 1      0.133272
# 2      0.13507...
# 0  0      0.192890
# 1      0.192418
# 2      0.19191...
# 0  0      0.190566
# 1      0.191206
# 2      0.19118...
# 0  0      0.161146
# 1      0.162465
# 2      0.16265...
# 0  0      0.244102
# 1      0.247012
# 2      0.24847...
# 0  0      0.184579
# 1      0.184977
# 2      0.18511...
# 0  0      0.247307
# 1      0.247571
# 2      0.24789...
# 0  0      0.161789
# 1      0.162851
# 2      0.16437...
# 0  0      0.202547
# 1      0.203011
# 2      0.20301...
# 0  0      0.251571
# 1      0.252447
# 2      0.25246...
# 0  0      0.125784
# 1      0.125963
# 2      0.12599...
# 0  0      0.194378
# 1      0.195889
# 2      0.19705...
# 0  0      0.193728
# 1      0.193733
# 2      0.19388...
# 0  0      0.170064
# 1      0.171149
# 2      0.17168...
#
#                                                   z0  \
# 0  0     -0.466988
# 1     -0.525535
# 2     -0.51864...
# 0  0     -0.177271
# 1     -0.255859
# 2     -0.27366...
# 0  0     -0.302442
# 1     -0.392072
# 2     -0.41519...
# 0  0     -0.592238
# 1     -0.551802
# 2     -0.55674...
# 0  0     -0.683895
# 1     -0.524278
# 2     -0.53158...
# 0  0     -0.404249
# 1     -0.475319
# 2     -0.47044...
# 0  0     -0.369699
# 1     -0.445957
# 2     -0.42505...
# 0  0     -0.245593
# 1     -0.241314
# 2     -0.24210...
# 0  0     -0.315485
# 1     -0.307551
# 2     -0.31661...
# 0  0     -0.457408
# 1     -0.494971
# 2     -0.53123...
# 0  0     -0.210443
# 1     -0.230291
# 2     -0.26208...
# 0  0     -0.225131
# 1     -0.173604
# 2     -0.18574...
# 0  0     -0.436286
# 1     -0.355991
# 2     -0.35219...
# 0  0     -0.199580
# 1     -0.235090
# 2     -0.22869...
# 0  0     -0.559420
# 1     -0.551236
# 2     -0.54186...
# 0  0     -0.249853
# 1     -0.263049
# 2     -0.28887...
# 0  0     -0.572183
# 1     -0.550837
# 2     -0.51995...
# 0  0     -0.416519
# 1     -0.540962
# 2     -0.51458...
# 0  0     -0.353282
# 1     -0.360431
# 2     -0.35661...
# 0  0     -0.422708
# 1     -0.433451
# 2     -0.45707...
# 0  0     -0.536068
# 1     -0.466076
# 2     -0.41914...
# 0  0     -0.473121
# 1     -0.476375
# 2     -0.46091...
# 0  0     -0.371470
# 1     -0.218417
# 2     -0.21494...
# 0  0     -0.214172
# 1     -0.210620
# 2     -0.20782...
# 0  0     -0.168022
# 1     -0.172880
# 2     -0.19395...
# 0  0     -0.264519
# 1     -0.396446
# 2     -0.35530...
# 0  0     -0.364965
# 1     -0.325412
# 2     -0.33248...
# 0  0     -0.197415
# 1     -0.229993
# 2     -0.21531...
# 0  0     -0.167701
# 1     -0.161883
# 2     -0.14554...
# 0  0     -0.350498
# 1     -0.357031
# 2     -0.33368...
# 0  0     -0.249208
# 1     -0.271928
# 2     -0.27030...
# 0  0     -0.134957
# 1     -0.166055
# 2     -0.18565...
# 0  0     -0.234704
# 1     -0.285173
# 2     -0.31339...
# 0  0     -0.235131
# 1     -0.279592
# 2     -0.27701...
# 0  0     -0.441293
# 1     -0.465971
# 2     -0.48469...
# 0  0     -0.274899
# 1     -0.274990
# 2     -0.25495...
# 0  0     -0.249168
# 1     -0.239161
# 2     -0.27157...
# 0  0     -0.185682
# 1     -0.163424
# 2     -0.21241...
# 0  0     -0.468270
# 1     -0.468742
# 2     -0.42195...
# 0  0     -0.207669
# 1     -0.235984
# 2     -0.26379...
# 0  0     -0.324120
# 1     -0.311799
# 2     -0.37339...
# 0  0     -0.277871
# 1     -0.200448
# 2     -0.20783...
# 0  0     -0.623932
# 1     -0.570626
# 2     -0.49522...
# 0  0     -0.325459
# 1     -0.249487
# 2     -0.22784...
# 0  0     -0.284561
# 1     -0.241686
# 2     -0.24297...
# 0  0     -0.261218
# 1     -0.261187
# 2     -0.25360...
# 0  0     -0.266691
# 1     -0.296034
# 2     -0.29731...
# 0  0     -0.292902
# 1     -0.245938
# 2     -0.25538...
# 0  0     -0.336123
# 1     -0.317309
# 2     -0.31351...
# 0  0     -0.686064
# 1     -0.552071
# 2     -0.51241...
# 0  0     -0.331417
# 1     -0.274717
# 2     -0.23353...
# 0  0     -0.260152
# 1     -0.277598
# 2     -0.31588...
# 0  0     -0.402766
# 1     -0.386996
# 2     -0.32161...
# 0  0     -0.510651
# 1     -0.513457
# 2     -0.51759...
# 0  0     -0.335751
# 1     -0.333343
# 2     -0.32745...
# 0  0     -0.195868
# 1     -0.249322
# 2     -0.26030...
#
#                                                   x1  \
# 0  0      0.462061
# 1      0.461956
# 2      0.46194...
# 0  0      0.430307
# 1      0.430652
# 2      0.43105...
# 0  0      0.560110
# 1      0.560236
# 2      0.56001...
# 0  0      0.449405
# 1      0.447885
# 2      0.44785...
# 0  0      0.421056
# 1      0.422365
# 2      0.42405...
# 0  0      0.443675
# 1      0.444117
# 2      0.44411...
# 0  0      0.416969
# 1      0.416837
# 2      0.41664...
# 0  0      0.430179
# 1      0.426253
# 2      0.42584...
# 0  0      0.445057
# 1      0.445201
# 2      0.44676...
# 0  0      0.428450
# 1      0.427097
# 2      0.42662...
# 0  0      0.408555
# 1      0.408502
# 2      0.40820...
# 0  0      0.466930
# 2     -0.56805...
# 0  0     -0.233819
# 1     -0.308054
# 2     -0.32666...
# 0  0     -0.361946
# 1     -0.446752
# 2     -0.46925...
# 0  0     -0.608377
# 1     -0.582869
# 2     -0.58570...
# 0  0     -0.707093
# 1     -0.562561
# 2     -0.56798...
# 0  0     -0.456130
# 1     -0.517302
# 2     -0.51419...
# 0  0     -0.420350
# 1     -0.496074
# 2     -0.47419...
# 0  0     -0.299830
# 1     -0.294405
# 2     -0.29577...
# 0  0     -0.374711
# 1     -0.366288
# 2     -0.37212...
# 0  0     -0.509149
# 1     -0.541710
# 2     -0.57172...
# 0  0     -0.261302
# 1     -0.285987
# 2     -0.31797...
# 0  0     -0.277900
# 1     -0.224676
# 2     -0.23749...
# 0  0     -0.489700
# 1     -0.405827
# 2     -0.40284...
# 0  0     -0.255375
# 1     -0.293751
# 2     -0.28660...
# 0  0     -0.603448
# 1     -0.602406
# 2     -0.59709...
# 0  0     -0.301675
# 1     -0.319522
# 2     -0.34679...
# 0  0     -0.612304
# 1     -0.598784
# 2     -0.57536...
# 0  0     -0.467909
# 1     -0.574840
# 2     -0.55353...
# 0  0     -0.405539
# 1     -0.416234
# 2     -0.41359...
# 0  0     -0.476841
# 1     -0.484180
# 2     -0.50266...
# 0  0     -0.586797
# 1     -0.520538
# 2     -0.47515...
# 0  0     -0.527252
# 1     -0.529750
# 2     -0.52160...
# 0  0     -0.434946
# 1     -0.277097
# 2     -0.27508...
# 0  0     -0.264713
# 1     -0.262698
# 2     -0.26049...
# 0  0     -0.216961
# 1     -0.222992
# 2     -0.24609...
# 0  0     -0.325935
# 1     -0.458090
# 2     -0.41946...
# 0  0     -0.417112
# 1     -0.380934
# 2     -0.38710...
# 0  0     -0.254376
# 1     -0.289584
# 2     -0.28531...
# 0  0     -0.219185
# 1     -0.216652
# 2     -0.20166...
# 0  0     -0.403443
# 1     -0.410498
# 2     -0.38518...
# 0  0     -0.300301
# 1     -0.325694
# 2     -0.32421...
# 0  0     -0.186800
# 1     -0.219813
# 2     -0.23856...
# 0  0     -0.289969
# 1     -0.345246
# 2     -0.37557...
# 0  0     -0.287739
# 1     -0.330200
# 2     -0.32768...
# 0  0     -0.497513
# 1     -0.519580
# 2     -0.53815...
# 0  0     -0.331664
# 1     -0.332597
# 2     -0.31149...
# 0  0     -0.304203
# 1     -0.290297
# 2     -0.32222...
# 0  0     -0.239316
# 1     -0.218317
# 2     -0.26663...
# 0  0     -0.526945
# 1     -0.526863
# 2     -0.47904...
# 0  0     -0.256161
# 1     -0.287933
# 2     -0.31586...
# 0  0     -0.384757
# 1     -0.376614
# 2     -0.44280...
# 0  0     -0.341594
# 1     -0.259290
# 2     -0.26647...
# 0  0     -0.669891
# 1     -0.625146
# 2     -0.55139...
# 0  0     -0.378824
# 1     -0.303483
# 2     -0.28135...
# 0  0     -0.340009
# 1     -0.298342
# 2     -0.29774...
# 0  0     -0.312206
# 1     -0.312481
# 2     -0.30548...
# 0  0     -0.318866
# 1     -0.351533
# 2     -0.35240...
# 1      0.185110
# 2      0.18654...
# 0  0      0.106589
# 1      0.105032
# 2      0.10439...
# 0  0      0.110978
# 1      0.110348
# 2      0.10970...
# 0  0      0.161635
# 1      0.161708
# 2      0.16174...
# 0  0      0.096769
# 1      0.096680
# 2      0.09650...
# 0  0      0.182910
# 1      0.184358
# 2      0.18546...
# 0  0      0.203375
# 1      0.203230
# 2      0.20260...
# 0  0      0.110689
# 1      0.111270
# 2      0.11359...
# 0  0      0.172840
# 1      0.172535
# 2      0.17214...
# 0  0      0.171317
# 1      0.172173
# 2      0.17216...
# 0  0      0.142637
# 1      0.143216
# 2      0.14328...
# 0  0      0.223478
# 1      0.227376
# 2      0.22922...
# 0  0      0.164610
# 1      0.165182
# 2      0.16560...
# 0  0      0.225513
# 1      0.226981
# 2      0.22772...
# 0  0      0.140804
# 1      0.141558
# 2      0.14327...
# 0  0      0.181484
# 1      0.181733
# 2      0.18174...
# 0  0      0.231543
# 1      0.232699
# 2      0.23286...
# 0  0      0.103114
# 1      0.103609
# 2      0.10383...
# 0  0      0.175954
# 1      0.176772
# 2      0.17741...
# 0  0      0.172749
# 1      0.172847
# 2      0.17298...
# 0  0      0.152395
# 1      0.153793
# 2      0.15454...
#
#                                                   z2  \
# 0  0     -0.519910
# 1     -0.577806
# 2     -0.56817...
# 0  0     -0.233898
# 1     -0.308116
# 2     -0.32672...
# 0  0     -0.361994
# 1     -0.446859
# 2     -0.46935...
# 0  0     -0.608417
# 1     -0.582760
# 2     -0.58560...
# 0  0     -0.707089
# 1     -0.562522
# 2     -0.56796...
# 0  0     -0.456134
# 1     -0.517315
# 2     -0.51421...
# 0  0     -0.420411
# 1     -0.496080
# 2     -0.47422...
# 0  0     -0.299950
# 1     -0.294541
# 2     -0.29591...
# 0  0     -0.374830
# 1     -0.366291
# 2     -0.37208...
# 0  0     -0.509133
# 1     -0.541711
# 2     -0.57171...
# 0  0     -0.261435
# 1     -0.286034
# 2     -0.31800...
# 0  0     -0.277958
# 1     -0.224748
# 2     -0.23755...
# 0  0     -0.489750
# 1     -0.405856
# 2     -0.40287...
# 0  0     -0.255448
# 1     -0.293855
# 2     -0.28670...
# 0  0     -0.603469
# 1     -0.602423
# 2     -0.59711...
# 0  0     -0.301759
# 1     -0.319526
# 2     -0.34674...
# 0  0     -0.612349
# 1     -0.598799
# 2     -0.57534...
# 0  0     -0.467911
# 1     -0.574899
# 2     -0.55359...
# 0  0     -0.405570
# 1     -0.416272
# 2     -0.41363...
# 0  0     -0.476783
# 1     -0.484144
# 2     -0.50265...
# 0  0     -0.586848
# 1     -0.520592
# 2     -0.47517...
# 0  0     -0.527363
# 1     -0.529855
# 2     -0.52169...
# 0  0     -0.434991
# 1     -0.277168
# 2     -0.27514...
# 0  0     -0.264787
# 1     -0.262737
# 2     -0.26050...
# 0  0     -0.217011
# 1     -0.223039
# 2     -0.24612...
# 0  0     -0.326027
# 1     -0.458181
# 2     -0.41954...
# 0  0     -0.417188
# 1     -0.380929
# 2     -0.38712...
# 0  0     -0.254583
# 1     -0.289811
# 2     -0.28550...
# 0  0     -0.219218
# 1     -0.216736
# 2     -0.20180...
# 0  0     -0.403647
# 1     -0.410704
# 2     -0.38538...
# 0  0     -0.300453
# 1     -0.325772
# 2     -0.32432...
# 0  0     -0.186855
# 1     -0.219829
# 2     -0.23856...
# 0  0     -0.290080
# 1     -0.345233
# 2     -0.37552...
# 0  0     -0.287818
# 1     -0.330208
# 2     -0.32770...
# 0  0     -0.497601
# 1     -0.519678
# 2     -0.53824...
# 0  0     -0.331751
# 1     -0.332704
# 2     -0.31164...
# 0  0     -0.304355
# 1     -0.290421
# 2     -0.32233...
# 0  0     -0.239494
# 1     -0.218497
# 2     -0.26678...
# 0  0     -0.527084
# 1     -0.526992
# 2     -0.47910...
# 0  0     -0.256306
# 1     -0.288068
# 2     -0.31599...
# 0  0     -0.384771
# 1     -0.376684
# 2     -0.44292...
# 0  0     -0.341667
# 1     -0.259388
# 2     -0.26656...
# 0  0     -0.669969
# 1     -0.625209
# 2     -0.55143...
# 0  0     -0.378900
# 1     -0.303509
# 2     -0.28138...
# 0  0     -0.340115
# 1     -0.298396
# 2     -0.29780...
# 0  0     -0.312385
# 1     -0.312655
# 2     -0.30565...
# 0  0     -0.318926
# 1     -0.351506
# 2     -0.35237...
# 0  0     -0.348598
# 1     -0.300965
# 2     -0.30902...
# 0  0     -0.396174
# 1     -0.377389
# 2     -0.37497...
# 0  0     -0.700701
# 1     -0.580446
# 2     -0.54253...
# 0  0     -0.390383
# 1     -0.327328
# 2     -0.28948...
# 0  0     -0.319137
# 1     -0.336114
# 2     -0.37379...
# 0  0     -0.457548
# 1     -0.441630
# 2     -0.37321...
# 0  0     -0.563547
# 1     -0.563637
# 2     -0.56614...
# 0  0     -0.385280
# 1     -0.384468
# 2     -0.37991...
# 0  0     -0.246614
# 1     -0.299467
# 2     -0.31138...
#
#                                                   x3  ...  \
# 0  0      0.480759
# 1      0.480579
# 2      0.48023...  ...
# 0  0      0.441724
# 1      0.442373
# 2      0.44297...  ...
# 0  0      0.574080
# 1      0.574546
# 2      0.57442...  ...
# 0  0      0.470972
# 1      0.467029
# 2      0.46674...  ...
# 0  0      0.443169
# 1      0.443685
# 2      0.44493...  ...
# 0  0      0.461129
# 1      0.461670
# 2      0.46168...  ...
# 0  0      0.430159
# 1      0.430163
# 2      0.42992...  ...
# 0  0      0.442756
# 1      0.437824
# 2      0.43715...  ...
# 0  0      0.454783
# 1      0.454920
# 2      0.45560...  ...
# 0  0      0.443604
# 1      0.443370
# 2      0.44340...  ...
# 0  0      0.420834
# 1      0.420755
# 2      0.42058...  ...
# 0  0      0.478335
# 1      0.478637
# 2      0.47866...  ...
# 0  0      0.474778
# 1      0.475809
# 2      0.47824...  ...
# 0  0      0.517951
# 1      0.517900
# 2      0.51709...  ...
# 0  0      0.490293
# 1      0.486020
# 2      0.48376...  ...
# 0  0      0.367653
# 1      0.369865
# 2      0.37095...  ...
# 0  0      0.516470
# 1      0.515150
# 2      0.51368...  ...
# 0  0      0.453377
# 1      0.455582
# 2      0.45702...  ...
# 0  0      0.385683
# 1      0.384812
# 2      0.38429...  ...
# 0  0      0.455282
# 1      0.456707
# 2      0.45794...  ...
# 0  0      0.513182
# 1      0.514893
# 2      0.51544...  ...
# 0  0      0.416557
# 1      0.413215
# 2      0.40922...  ...
# 0  0      0.551574
# 1      0.551560
# 2      0.55062...  ...
# 0  0      0.437303
# 1      0.436084
# 2      0.43591...  ...
# 0  0      0.426559
# 1      0.426691
# 2      0.42662...  ...
# 0  0      0.558221
# 1      0.558548
# 2      0.55806...  ...
# 0  0      0.465041
# 1      0.465192
# 2      0.46519...  ...
# 0  0      0.464409
# 1      0.464277
# 2      0.46424...  ...
# 0  0      0.445769
# 1      0.445008
# 2      0.44466...  ...
# 0  0      0.469674
# 1      0.469502
# 2      0.46873...  ...
# 0  0      0.407557
# 1      0.406247
# 2      0.40479...  ...
# 0  0      0.426244
# 1      0.423596
# 2      0.42323...  ...
# 0  0      0.380329
# 1      0.380811
# 2      0.38109...  ...
# 0  0      0.465121
# 1      0.465152
# 2      0.46515...  ...
# 0  0      0.522402
# 1      0.522543
# 2      0.52421...  ...
# 0  0      0.385156
# 1      0.384959
# 2      0.38493...  ...
# 0  0      0.473379
# 1      0.472835
# 2      0.47208...  ...
# 0  0      0.435601
# 1      0.433430
# 2      0.43322...  ...
# 0  0      0.513945
# 1      0.513001
# 2      0.51183...  ...
# 0  0      0.487065
# 1      0.487060
# 2      0.48713...  ...
# 0  0      0.573480
# 1      0.573611
# 2      0.57368...  ...
# 0  0      0.508794
# 1      0.509017
# 2      0.50890...  ...
# 0  0      0.497870
# 1      0.497637
# 2      0.49728...  ...
# 0  0      0.402599
# 1      0.404432
# 2      0.40555...  ...
# 0  0      0.420300
# 1      0.421223
# 2      0.42168...  ...
# 0  0      0.477647
# 1      0.477105
# 2      0.47658...  ...
# 0  0      0.459476
# 1      0.461472
# 2      0.46226...  ...
# 0  0      0.384834
# 1      0.384892
# 2      0.38499...  ...
# 0  0      0.424633
# 1      0.427928
# 2      0.43055...  ...
# 0  0      0.519977
# 1      0.518642
# 2      0.51787...  ...
# 0  0      0.375068
# 1      0.374128
# 2      0.37087...  ...
# 0  0      0.409222
# 1      0.410055
# 2      0.41023...  ...
# 0  0      0.464605
# 1      0.461568
# 2      0.45908...  ...
# 0  0      0.436462
# 1      0.433047
# 2      0.43106...  ...
# 0  0      0.483141
# 1      0.482855
# 2      0.48236...  ...
# 0  0      0.488886
# 1      0.488681
# 2      0.48851...  ...
#
#                                                  z30  \
# 0  0      0.966136
# 1      0.981824
# 2      0.99653...
# 0  0      0.633697
# 1      0.796666
# 2      0.80337...
# 0  0      0.882791
# 1      0.867950
# 2      0.87849...
# 0  0      0.847385
# 1      0.920662
# 2      0.90322...
# 0  0      1.132791
# 1      0.956265
# 2      0.94912...
# 0  0      0.844667
# 1      0.867498
# 2      0.88203...
# 0  0      0.819983
# 1      0.828142
# 2      0.85222...
# 0  0      0.748321
# 1      0.844078
# 2      0.86298...
# 1      0.976328
# 2      0.97752...
# 0  0      0.881018
# 1      0.881018
# 2      0.88173...
# 0  0      0.881213
# 1      0.889288
# 2      0.89158...
# 0  0      0.960281
# 1      0.969854
# 2      0.97112...
# 0  0      0.829252
# 1      0.838990
# 2      0.83974...
# 0  0      0.898616
# 1      0.899551
# 2      0.89990...
# 0  0      0.970838
# 1      0.964786
# 2      0.96406...
# 0  0      0.842707
# 1      0.835635
# 2      0.83268...
#
#                                                  z31  \
# 0  0     -0.075619
# 1      0.085495
# 2      0.05858...
# 0  0     -0.280918
# 1     -0.317055
# 2     -0.31674...
# 0  0     -0.143358
# 1     -0.138922
# 2     -0.13952...
# 0  0     -0.199213
# 1     -0.466466
# 2     -0.44120...
# 0  0      0.027642
# 1     -0.057642
# 2     -0.06442...
# 0  0      0.150870
# 1      0.176186
# 2      0.18979...
# 0  0      0.105350
# 1      0.010037
# 2      0.03425...
# 0  0     -0.009629
# 1      0.169904
# 2      0.09587...
# 0  0      0.056402
# 1     -0.092491
# 2     -0.04652...
# 0  0      0.038307
# 1     -0.043231
# 2     -0.07981...
# 0  0     -0.025696
# 1     -0.135128
# 2     -0.13190...
# 0  0     -0.240281
# 1     -0.124036
# 2     -0.11736...
# 0  0      0.232393
# 1      0.196633
# 2      0.18672...
# 0  0     -0.059656
# 1      0.049887
# 2      0.02421...
# 0  0     -0.172704
# 1      0.136647
# 2      0.15408...
# 0  0      0.041505
# 1     -0.006041
# 2     -0.00812...
# 0  0     -0.080050
# 1      0.050349
# 2      0.00692...
# 0  0      0.217764
# 1      0.129885
# 2      0.12753...
# 0  0     -0.016255
# 1      0.051051
# 2      0.03477...
# 0  0      0.089183
# 1      0.110286
# 2      0.14011...
# 0  0      0.108802
# 1      0.039707
# 2      0.04625...
# 0  0     -0.172630
# 1     -0.223017
# 2     -0.20226...
# 0  0     -0.115695
# 1     -0.179539
# 2     -0.20731...
# 0  0     -0.167199
# 1     -0.176462
# 2     -0.07520...
# 0  0     -0.067571
# 1     -0.142600
# 2     -0.17486...
# 0  0     -0.146750
# 1     -0.218317
# 2     -0.20975...
# 0  0      0.128527
# 1      0.160232
# 2      0.16431...
# 0  0     -0.178207
# 1     -0.174173
# 2     -0.16197...
# 0  0     -0.080351
# 1     -0.022418
# 2     -0.00297...
# 0  0      0.198717
# 1      0.314806
# 2      0.35445...
# 0  0      0.017896
# 1      0.016481
# 2      0.01521...
# 0  0     -0.227304
# 1     -0.207465
# 2     -0.18396...
# 0  0     -0.034004
# 1     -0.079698
# 2     -0.11135...
# 0  0     -0.307287
# 1     -0.086535
# 2     -0.12047...
# 0  0     -0.191714
# 1     -0.039600
# 2     -0.04335...
# 0  0     -0.066232
# 1     -0.091914
# 2     -0.09051...
# 0  0      0.199539
# 1      0.184449
# 2      0.25391...
# 0  0     -0.009791
# 1      0.009881
# 2      0.00793...
# 0  0     -0.014573
# 1     -0.144342
# 2     -0.18421...
# 0  0      0.141211
# 1      0.162752
# 2      0.13675...
# 0  0     -0.114166
# 1     -0.139579
# 2      167...
# 0  0      175.769453
# 1      174.237964
# 2      173...
# 0  0      170.563265
# 1      169.521344
# 2      168...
# 0  0      176.019710
# 1      174.106085
# 2      173...
# 0  0      178.269222
# 1      176.967881
# 2      175...
# 0  0      172.942419
# 1      176.635562
# 2      178...
# 0  0      174.295272
# 1      173.824126
# 2      173...
# 0  0      179.477914
# 1      179.802550
# 2      179...
# 0  0      178.577108
# 1      179.399804
# 2      178...
# 0  0      173.060853
# 1      171.260743
# 2      170...
# 0  0      177.330304
# 1      178.483741
# 2      173...
# 0  0      173.874485
# 1      172.413374
# 2      171...
# 0  0      178.440340
# 1      178.671734
# 2      178...
# 0  0      173.682118
# 1      172.975499
# 2      172...
# 0  0      176.893924
# 1      176.471946
# 2      176...
# 0  0      170.254625
# 1      168.053131
# 2      166...
# 0  0      170.387660
# 1      171.079322
# 2      172...
# 0  0      176.427033
# 1      178.319765
# 2      177...
# 0  0      176.207265
# 1      179.616827
# 2      179...
# 0  0      162.558102
# 1      165.465450
# 2      166...
# 0  0      177.745842
# 1      178.754511
# 2      174...
# 0  0      171.066533
# 1      178.621197
# 2      178...
# 0  0      174.163740
# 1      173.630540
# 2      170...
# 0  0      177.943340
# 1      176.713041
# 2      174...
# 0  0      176.628885
# 1      179.303583
# 2      178...
# 0  0      170.109602
# 1      168.038435
# 2      167...
# 0  0      174.017429
# 1      174.680872
# 2      175...
# 0  0      176.139622
# 1      177.478697
# 2      178...
# 0  0      179.953103
# 1      179.336196
# 2      178...
# 0  0      168.015532
# 1      166.693225
# 2      166...
# 0  0      179.509629
# 1      179.056267
# 2      178...
# 0  0      169.153034
# 1      168.905218
# 2      167...
# 0  0      169.475414
# 1      174.465962
# 2      178...
# 0  0      175.256284
# 1      173.919276
# 2      172...
# 0  0      170.330107
# 1      168.995704
# 2      166...
# 0  0      178.997746
# 1      174.958575
# 2      171...
# 0  0      165.416958
# 1      165.444544
# 2      166...
# 0  0      167.092704
# 1      168.907001
# 2      170...
# 0  0      163.479742
# 1      164.824043
# 2      166...
#
# [56 rows x 102 columns]

# %%
print("X_train_df's shape: " + str(X_train_df.shape) + '\n' + "y_train's length: " + str(len(y_train)))
# Out:
# X_train_df's shape: (56, 102)
# y_train's length: 56

# %%
# Fix the index so that they don't all have value of 0
X_train_df = X_train_df.reset_index(drop=True)

# %%
# Drop all other columns apart from the specific
X_train_df_1 = X_train_df.drop(X_train_df.columns.difference(['elbow_hip_angle']), 1) 
X_train_df_2 = X_train_df.drop(X_train_df.columns.difference(['bicep_angle']), 1)
X_train_df_3 = X_train_df.drop(X_train_df.columns.difference(['hip_angle']), 1)

# %%
# Prepare the testing set same as the training set
X_test_df = pd.DataFrame()

for vid in X_test:
    df = pd.DataFrame(convert_list_to_df(vid))
    df['elbow_hip_angle'] = df.apply(lambda row: get_angle(row, 23, 11, 13), axis=1)
    df['bicep_angle'] = df.apply(lambda row: get_angle(row, 15, 13, 11), axis=1)
    df['hip_angle'] = df.apply(lambda row: get_angle(row, 11, 23, 27), axis=1)
    X_test_df = X_test_df.append(df_reshape(df))

# %%
X_test_df_1 = X_test_df.drop(X_test_df.columns.difference(['elbow_hip_angle']), 1) 
X_test_df_2 = X_test_df.drop(X_test_df.columns.difference(['bicep_angle']), 1)
X_test_df_3 = X_test_df.drop(X_test_df.columns.difference(['hip_angle']), 1)

# %%
print("X_test_df's shape: " + str(X_test_df.shape) + '\n' + "y_test's length: " + str(len(y_test)))
# Out:
# X_test_df's shape: (29, 102)
# y_test's length: 29

# %% [markdown]
# # 2. Train & Evaluate Models

# %%
# List to keep track of metrics for each
elbow_hip_scores = [] # Elbow-hip angle (13, 11, 23) - keypoint numbers, see above for reference
bicep_scores = [] # Bicep angle (15, 13, 11)
hip_scores = [] # Hip angle (11, 23, 25)

def evaluate_model(model_name, prediction, display_matrix=False):
    acc = metrics.accuracy_score(y_test, prediction)
    f1 = f1_score(y_test, prediction, average='micro')
    precision = precision_score(y_test, prediction, average='macro')
    recall = recall_score(y_test, prediction, average='macro')

    model_metrics = {'Classifier': model_name, 
                   'Accuracy': acc, 
                   'Precision': precision, 
                   'Recall': recall,
                   'F1 Score': f1}

    if display_matrix:
        labels = ['elbow', 'shoulder', 'good']
        cm = confusion_matrix(y_test, prediction, labels=labels)
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
        disp.plot()
        plt.title(model_name)
        plt.show()

    return model_metrics

# %% [markdown]
# ## Using Elbow-Hip Angle (13, 11, 23)

# %% [markdown]
# ### Distance-based

# %% [markdown]
# #### KNeighbours Time Series

# %%
clf = KNeighborsTimeSeriesClassifier()
clf.fit(X_train_df_1, y_train)
y_pred = clf.predict(X_test_df_1)

scores = evaluate_model('KNeighbours', y_pred)
elbow_hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'KNeighbours', 'Accuracy': 0.8620689655172413, 'Precision': 0.85, 'Recall': 0.8268398268398268, 'F1 Score': 0.8620689655172413}

# %% [markdown]
# #### Elastic Ensemble

# %%
clf = ElasticEnsemble(
    proportion_of_param_options=0.1,
    proportion_train_for_test=0.1,
    distance_measures = ["dtw","ddtw"],
    majority_vote=True,
    random_state=1
)
clf.fit(X_train_df_1, y_train)
y_pred = clf.predict(X_test_df_1)

scores = evaluate_model('Elastic', y_pred)
elbow_hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'Elastic', 'Accuracy': 0.7931034482758621, 'Precision': 0.7606837606837606, 'Recall': 0.7316017316017316, 'F1 Score': 0.7931034482758621}

# %% [markdown]
# #### Proximity Forest

# %%
clf = ProximityForest(n_estimators=5, random_state=1)
clf.fit(X_train_df_1, pd.Series(y_train))
y_pred = clf.predict(X_test_df_1)

scores = evaluate_model('Proximity Forest', y_pred)
elbow_hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'Proximity Forest', 'Accuracy': 0.3448275862068966, 'Precision': 0.15151515151515152, 'Recall': 0.30303030303030304, 'F1 Score': 0.3448275862068966}
# C:\Users\abid5.000\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Dictionary-based

# %% [markdown]
# #### IndividualBOSS

# %%
clf = IndividualBOSS()
clf.fit(X_train_df_1, y_train)
y_pred = clf.predict(X_test_df_1)

scores = evaluate_model('IndividualBOSS', y_pred)
elbow_hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'IndividualBOSS', 'Accuracy': 0.6206896551724138, 'Precision': 0.601010101010101, 'Recall': 0.5974025974025975, 'F1 Score': 0.6206896551724138}

# %% [markdown]
# IndividualBOSS doesn't seem to work very well.

# %% [markdown]
# #### BOSSEnsemble

# %%
clf = BOSSEnsemble(max_ensemble_size=5, random_state=1)
clf.fit(X_train_df_1, y_train)
y_pred = clf.predict(X_test_df_1)

scores = evaluate_model('BOSSEnsemble', y_pred, True)
elbow_hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'BOSSEnsemble', 'Accuracy': 0.896551724137931, 'Precision': 0.9209401709401709, 'Recall': 0.8571428571428571, 'F1 Score': 0.896551724137931}

# %% [markdown]
# EnsembleBOSS works a lot better.

# %% [markdown]
# #### WEASEL

# %%
clf = WEASEL(window_inc=10, random_state=1)
clf.fit(X_train_df_1, y_train)
y_pred = clf.predict(X_test_df_1)

scores = evaluate_model('WEASEL', y_pred, True)
elbow_hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'WEASEL', 'Accuracy': 0.9310344827586207, 'Precision': 0.9444444444444443, 'Recall': 0.9047619047619048, 'F1 Score': 0.9310344827586207}

# %% [markdown]
# ### Interval-based

# %% [markdown]
# #### Time Series Forest

# %%
# Train classifier
clf = TimeSeriesForestClassifier(random_state=1)
clf.fit(X_train_df_1, y_train)
y_pred = clf.predict(X_test_df_1)

scores = evaluate_model('Time Forest', y_pred, True)
elbow_hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'Time Forest', 'Accuracy': 0.9310344827586207, 'Precision': 0.9220779220779222, 'Recall': 0.9220779220779222, 'F1 Score': 0.9310344827586207}

# %% [markdown]
# ### Kernel-based

# %%
clf = Arsenal(num_kernels=200, n_estimators=5, random_state=1)
clf.fit(X_train_df_1, y_train)
y_pred = clf.predict(X_test_df_1)

scores = evaluate_model('Arsenal', y_pred)
elbow_hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'Arsenal', 'Accuracy': 0.9655172413793104, 'Precision': 0.9722222222222222, 'Recall': 0.9523809523809524, 'F1 Score': 0.9655172413793104}

# %% [markdown]
# ### Shapelet-based

# %%
clf = ShapeletTransformClassifier(
    estimator=RotationForest(n_estimators=3),
    n_shapelet_samples=500,
    max_shapelets=20,
    batch_size=100,
    random_state=1
)
clf.fit(X_train_df_1, y_train)
y_pred = clf.predict(X_test_df_1)

scores = evaluate_model('Shapelet', y_pred)
elbow_hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'Shapelet', 'Accuracy': 0.6896551724137931, 'Precision': 0.6641025641025641, 'Recall': 0.658008658008658, 'F1 Score': 0.6896551724137931}

# %% [markdown]
# ### Hybrid

# %%
clf = HIVECOTEV1(
    stc_params={
        "estimator": RotationForest(n_estimators=3),
        "n_shapelet_samples": 500,
        "max_shapelets": 20,
        "batch_size": 100,
    },
    tsf_params={"n_estimators": 10},
    rise_params={"n_estimators": 10},
    cboss_params={"n_parameter_samples": 25, "max_ensemble_size": 5},
    random_state=1
)
clf.fit(X_train_df_1, y_train)
y_pred = clf.predict(X_test_df_1)

scores = evaluate_model('HIVECOTEV1', y_pred, True)
elbow_hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'HIVECOTEV1', 'Accuracy': 1.0, 'Precision': 1.0, 'Recall': 1.0, 'F1 Score': 1.0}

# %% [markdown]
# ## Using Bicep Angle (11, 13, 15)

# %% [markdown]
# ### Distance-based

# %% [markdown]
# #### KNeighbours Time Series

# %%
clf = KNeighborsTimeSeriesClassifier()
clf.fit(X_train_df_2, y_train)
y_pred = clf.predict(X_test_df_2)

scores = evaluate_model('KNeighbours', y_pred)
bicep_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'KNeighbours', 'Accuracy': 0.7931034482758621, 'Precision': 0.8285714285714286, 'Recall': 0.8181818181818182, 'F1 Score': 0.7931034482758621}

# %% [markdown]
# #### Elastic Ensemble

# %%
clf = ElasticEnsemble(
    proportion_of_param_options=0.1,
    proportion_train_for_test=0.1,
    distance_measures = ["dtw","ddtw"],
    majority_vote=True,
    random_state=1
)
clf.fit(X_train_df_2, y_train)
y_pred = clf.predict(X_test_df_2)

scores = evaluate_model('Elastic', y_pred)
bicep_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'Elastic', 'Accuracy': 0.7586206896551724, 'Precision': 0.7673160173160173, 'Recall': 0.7186147186147186, 'F1 Score': 0.7586206896551724}

# %% [markdown]
# ### Dictionary-based

# %% [markdown]
# #### BOSSEnsemble

# %%
clf = BOSSEnsemble(max_ensemble_size=5, random_state=1)
clf.fit(X_train_df_2, y_train)
y_pred = clf.predict(X_test_df_2)

scores = evaluate_model('BOSSEnsemble', y_pred, True)
bicep_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'BOSSEnsemble', 'Accuracy': 0.896551724137931, 'Precision': 0.8863636363636364, 'Recall': 0.8744588744588745, 'F1 Score': 0.896551724137931}

# %% [markdown]
# #### WEASEL

# %%
clf = WEASEL(window_inc=3, random_state=1)
clf.fit(X_train_df_2, y_train)
y_pred = clf.predict(X_test_df_2)

scores = evaluate_model('WEASEL', y_pred, True)
bicep_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'WEASEL', 'Accuracy': 0.896551724137931, 'Precision': 0.8912698412698412, 'Recall': 0.8917748917748919, 'F1 Score': 0.896551724137931}

# %% [markdown]
# ### Interval-based

# %% [markdown]
# #### Time Series Forest

# %%
clf = TimeSeriesForestClassifier(random_state=1)
clf.fit(X_train_df_2, y_train)
y_pred = clf.predict(X_test_df_2)

scores = evaluate_model('Time Forest', y_pred)
bicep_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'Time Forest', 'Accuracy': 0.7586206896551724, 'Precision': 0.7537647537647537, 'Recall': 0.7532467532467533, 'F1 Score': 0.7586206896551724}

# %% [markdown]
# ### Kernel-based

# %%
clf = Arsenal(num_kernels=200, n_estimators=5, random_state=1)
clf.fit(X_train_df_2, y_train)
y_pred = clf.predict(X_test_df_2)

scores = evaluate_model('Arsenal', y_pred, True)
bicep_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'Arsenal', 'Accuracy': 0.9310344827586207, 'Precision': 0.9419191919191919, 'Recall': 0.9220779220779222, 'F1 Score': 0.9310344827586207}

# %% [markdown]
# ### Shapelet-based

# %%
clf = ShapeletTransformClassifier(
    estimator=RotationForest(n_estimators=3),
    n_shapelet_samples=500,
    max_shapelets=20,
    batch_size=100,
    random_state=1
)
clf.fit(X_train_df_2, y_train)
y_pred = clf.predict(X_test_df_2)

scores = evaluate_model('Shapelet', y_pred)
bicep_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'Shapelet', 'Accuracy': 0.7931034482758621, 'Precision': 0.7682539682539682, 'Recall': 0.7662337662337663, 'F1 Score': 0.7931034482758621}

# %% [markdown]
# ### Hybrid

# %%
clf = HIVECOTEV1(
    stc_params={
        "estimator": RotationForest(n_estimators=3),
        "n_shapelet_samples": 500,
        "max_shapelets": 20,
        "batch_size": 100,
    },
    tsf_params={"n_estimators": 10},
    rise_params={"n_estimators": 10},
    cboss_params={"n_parameter_samples": 25, "max_ensemble_size": 5},
    random_state=1
)
clf.fit(X_train_df_2, y_train)
y_pred = clf.predict(X_test_df_2)

scores = evaluate_model('HIVECOTEV1', y_pred)
bicep_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'HIVECOTEV1', 'Accuracy': 0.8620689655172413, 'Precision': 0.888111888111888, 'Recall': 0.8441558441558442, 'F1 Score': 0.8620689655172413}

# %% [markdown]
# ## Using Hip Angle (11, 23, 25)

# %% [markdown]
# ### Distance-based

# %% [markdown]
# #### KNeighbours Time Series

# %%
clf = KNeighborsTimeSeriesClassifier()
clf.fit(X_train_df_3, y_train)
y_pred = clf.predict(X_test_df_3)

scores = evaluate_model('KNeighbours', y_pred)
hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'KNeighbours', 'Accuracy': 0.6206896551724138, 'Precision': 0.6435185185185185, 'Recall': 0.6320346320346321, 'F1 Score': 0.6206896551724138}

# %% [markdown]
# #### Elastic Ensemble

# %%
clf = ElasticEnsemble(
    proportion_of_param_options=0.1,
    proportion_train_for_test=0.1,
    distance_measures = ["dtw","ddtw"],
    majority_vote=True,
    random_state=1
)
clf.fit(X_train_df_3, y_train)
y_pred = clf.predict(X_test_df_3)

scores = evaluate_model('Elastic', y_pred)
hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'Elastic', 'Accuracy': 0.6206896551724138, 'Precision': 0.728937728937729, 'Recall': 0.5800865800865801, 'F1 Score': 0.6206896551724138}

# %% [markdown]
# ### Dictionary-based

# %% [markdown]
# #### BOSSEnsemble

# %%
clf = BOSSEnsemble(max_ensemble_size=5, random_state=1)
clf.fit(X_train_df_3, y_train)
y_pred = clf.predict(X_test_df_3)

scores = evaluate_model('BOSSEnsemble', y_pred)
hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'BOSSEnsemble', 'Accuracy': 0.5862068965517241, 'Precision': 0.6476608187134502, 'Recall': 0.5844155844155844, 'F1 Score': 0.5862068965517241}

# %% [markdown]
# #### WEASEL

# %%
clf = WEASEL(window_inc=3, random_state=1)
clf.fit(X_train_df_3, y_train)
y_pred = clf.predict(X_test_df_3)

scores = evaluate_model('WEASEL', y_pred, True)
hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'WEASEL', 'Accuracy': 0.7241379310344828, 'Precision': 0.7718253968253969, 'Recall': 0.7402597402597402, 'F1 Score': 0.7241379310344829}

# %% [markdown]
# ### Interval-based

# %% [markdown]
# #### Time Series Forest

# %%
clf = TimeSeriesForestClassifier(random_state=1)
clf.fit(X_train_df_3, y_train)
y_pred = clf.predict(X_test_df_3)

scores = evaluate_model('Time Forest', y_pred)
hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'Time Forest', 'Accuracy': 0.5517241379310345, 'Precision': 0.6746031746031745, 'Recall': 0.5367965367965368, 'F1 Score': 0.5517241379310345}

# %% [markdown]
# ### Kernel-based

# %%
clf = Arsenal(num_kernels=200, n_estimators=5, random_state=1)
clf.fit(X_train_df_3, y_train)
y_pred = clf.predict(X_test_df_3)

scores = evaluate_model('Arsenal', y_pred)
hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'Arsenal', 'Accuracy': 0.6551724137931034, 'Precision': 0.7275132275132276, 'Recall': 0.645021645021645, 'F1 Score': 0.6551724137931034}

# %% [markdown]
# ### Shapelet-based

# %%
clf = ShapeletTransformClassifier(
    estimator=RotationForest(n_estimators=3),
    n_shapelet_samples=500,
    max_shapelets=20,
    batch_size=100,
    random_state=1
)
clf.fit(X_train_df_3, y_train)
y_pred = clf.predict(X_test_df_3)

scores = evaluate_model('Shapelet', y_pred)
hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'Shapelet', 'Accuracy': 0.6206896551724138, 'Precision': 0.6435185185185185, 'Recall': 0.6320346320346321, 'F1 Score': 0.6206896551724138}

# %% [markdown]
# ### Hybrid

# %%
clf = HIVECOTEV1(
    stc_params={
        "estimator": RotationForest(n_estimators=3),
        "n_shapelet_samples": 500,
        "max_shapelets": 20,
        "batch_size": 100,
    },
    tsf_params={"n_estimators": 10},
    rise_params={"n_estimators": 10},
    cboss_params={"n_parameter_samples": 25, "max_ensemble_size": 5},
    random_state=1
)
clf.fit(X_train_df_3, y_train)
y_pred = clf.predict(X_test_df_3)

scores = evaluate_model('HIVECOTEV1', y_pred)
hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'HIVECOTEV1', 'Accuracy': 0.6551724137931034, 'Precision': 0.7833333333333333, 'Recall': 0.645021645021645, 'F1 Score': 0.6551724137931034}

# %% [markdown]
# # 3. Choose Best Model

# %% [markdown]
# ## Best Classifier for Elbow-Hip Angle

# %%
elbow_hip_scores_df = pd.DataFrame(elbow_hip_scores)
elbow_hip_scores_df = elbow_hip_scores_df.sort_values(by = ['F1 Score'], ascending = False)
elbow_hip_scores_df
# Out:
#          Classifier  Accuracy  Precision    Recall  F1 Score
# 9        HIVECOTEV1  1.000000   1.000000  1.000000  1.000000
# 7           Arsenal  0.965517   0.972222  0.952381  0.965517
# 5            WEASEL  0.931034   0.944444  0.904762  0.931034
# 6       Time Forest  0.931034   0.922078  0.922078  0.931034
# 4      BOSSEnsemble  0.896552   0.920940  0.857143  0.896552
# 0       KNeighbours  0.862069   0.850000  0.826840  0.862069
# 1           Elastic  0.793103   0.760684  0.731602  0.793103
# 8          Shapelet  0.689655   0.664103  0.658009  0.689655
# 3    IndividualBOSS  0.620690   0.601010  0.597403  0.620690
# 2  Proximity Forest  0.344828   0.151515  0.303030  0.344828

# %%
elbow_hip_scores_df.plot.bar(x = 'Classifier', figsize = (18,5))
plt.title('Comparison of Classifiers for Elbow-Hip Angle')
plt.show()

# %% [markdown]
# The elbow-hip angle seems like a good feature, a lot of the classifiers work very well.

# %% [markdown]
# ## Best Classifier for Bicep Angle

# %%
bicep_scores_df = pd.DataFrame(bicep_scores)
bicep_scores_df = bicep_scores_df.sort_values(by = ['F1 Score'], ascending = False)
bicep_scores_df
# Out:
#      Classifier  Accuracy  Precision    Recall  F1 Score
# 5       Arsenal  0.931034   0.941919  0.922078  0.931034
# 2  BOSSEnsemble  0.896552   0.886364  0.874459  0.896552
# 3        WEASEL  0.896552   0.891270  0.891775  0.896552
# 7    HIVECOTEV1  0.862069   0.888112  0.844156  0.862069
# 0   KNeighbours  0.793103   0.828571  0.818182  0.793103
# 6      Shapelet  0.793103   0.768254  0.766234  0.793103
# 1       Elastic  0.758621   0.767316  0.718615  0.758621
# 4   Time Forest  0.758621   0.753765  0.753247  0.758621

# %%
bicep_scores_df.plot.bar(x = 'Classifier', figsize = (18,5))
plt.title('Comparison of Classifiers for Bicep Angle')
plt.show()

# %% [markdown]
# While it was difficult to see a pattern with the bicep angle in the videos-to-frames notebook, there are some very good classifiers here.

# %% [markdown]
# ## Best Classifier for Hip Angle

# %%
hip_scores_df = pd.DataFrame(hip_scores)
hip_scores_df = hip_scores_df.sort_values(by = ['F1 Score'], ascending = False)
hip_scores_df
# Out:
#      Classifier  Accuracy  Precision    Recall  F1 Score
# 3        WEASEL  0.724138   0.771825  0.740260  0.724138
# 5       Arsenal  0.655172   0.727513  0.645022  0.655172
# 7    HIVECOTEV1  0.655172   0.783333  0.645022  0.655172
# 0   KNeighbours  0.620690   0.643519  0.632035  0.620690
# 1       Elastic  0.620690   0.728938  0.580087  0.620690
# 6      Shapelet  0.620690   0.643519  0.632035  0.620690
# 2  BOSSEnsemble  0.586207   0.647661  0.584416  0.586207
# 4   Time Forest  0.551724   0.674603  0.536797  0.551724

# %%
hip_scores_df.plot.bar(x = 'Classifier', figsize = (18,5))
plt.title('Comparison of Classifiers for Hip Angle')
plt.show()

# %% [markdown]
# The classifiers don't perform amazingly by just looking at the hip angle.

# %% [markdown]
# Univariate classifiers do a good job, but we can combine them with multivariate classification for even better performance.
