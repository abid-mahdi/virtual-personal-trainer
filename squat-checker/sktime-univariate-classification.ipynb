# %% [markdown]
# # Analysing Form using Sktime Univariate Classification

# %% [markdown]
# Author: Abid Mahdi, University of Southampton. 28/03/2022. am14g19@soton.ac.uk.
#
# Exploring classifiers to analyse univariate time series of the squat dataset.
#
# ## TOC:
# 0. [Import Libraries & Setup Helper Functions](#0.-Import-Libraries-&-Setup)
# 1. [Setup Training & Testing Sets](#1.-Setup-Training-&-Testing-Sets)
# 2. [Train & Evaluate Models](#2.-Train-&-Evaluate-Models)
#     * [Using Knee-Hip Difference](#Using-Knee-Hip-y-difference-Distance-(23,-25))
#     * [Using Hip Angle](#Using-Hip-Angle-(11,-23,-25))
# 3. [Choosing the Best Model](#3.-Choose-Best-Model)
#     * [Best for Knee-Hip Difference](#Best-Classifier-for-Knee-Hip-Difference)
#     * [Best for Hip Angle](#Best-Classifier-for-Hip-Angle)

# %% [markdown]
# # 0. Import Libraries & Setup

# %%
! pip install sktime

import sktime
from sktime.classification.all import TimeSeriesForestClassifier, KNeighborsTimeSeriesClassifier, ElasticEnsemble, ProximityForest
from sktime.classification.shapelet_based import ShapeletTransformClassifier
from sktime.classification.kernel_based import Arsenal
from sktime.classification.hybrid import HIVECOTEV1
from sktime.classification.dictionary_based import IndividualBOSS, BOSSEnsemble, WEASEL, MUSE
from sktime.contrib.vector_classifiers._rotation_forest import RotationForest

from sklearn.model_selection import train_test_split

import sklearn.metrics as metrics
from sklearn.metrics import accuracy_score, recall_score, precision_score ,f1_score
from sklearn.metrics import classification_report, ConfusionMatrixDisplay, confusion_matrix

import pickle
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: sktime in c:\users\abid5.000\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: numpy<1.22,>=1.21.0 in c:\users\abid5.000\anaconda3\lib\site-packages (from sktime) (1.21.5)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\abid5.000\anaconda3\lib\site-packages (from sktime) (0.12.2)
# Requirement already satisfied: pandas<1.5.0,>=1.1.0 in c:\users\abid5.000\anaconda3\lib\site-packages (from sktime) (1.2.4)
# Requirement already satisfied: scipy<1.8.0 in c:\users\abid5.000\anaconda3\lib\site-packages (from sktime) (1.6.2)
# Requirement already satisfied: numba>=0.53 in c:\users\abid5.000\anaconda3\lib\site-packages (from sktime) (0.53.1)
# Requirement already satisfied: scikit-learn>=0.24.0 in c:\users\abid5.000\anaconda3\lib\site-packages (from sktime) (0.24.1)
# Requirement already satisfied: deprecated>=1.2.13 in c:\users\abid5.000\anaconda3\lib\site-packages (from sktime) (1.2.13)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\abid5.000\anaconda3\lib\site-packages (from deprecated>=1.2.13->sktime) (1.12.1)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in c:\users\abid5.000\anaconda3\lib\site-packages (from numba>=0.53->sktime) (0.36.0)
# Requirement already satisfied: setuptools in c:\users\abid5.000\anaconda3\lib\site-packages (from numba>=0.53->sktime) (52.0.0.post20210125)
# Requirement already satisfied: pytz>=2017.3 in c:\users\abid5.000\anaconda3\lib\site-packages (from pandas<1.5.0,>=1.1.0->sktime) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\abid5.000\anaconda3\lib\site-packages (from pandas<1.5.0,>=1.1.0->sktime) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\abid5.000\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas<1.5.0,>=1.1.0->sktime) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\abid5.000\anaconda3\lib\site-packages (from scikit-learn>=0.24.0->sktime) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\abid5.000\anaconda3\lib\site-packages (from scikit-learn>=0.24.0->sktime) (1.0.1)
# Requirement already satisfied: patsy>=0.5 in c:\users\abid5.000\anaconda3\lib\site-packages (from statsmodels>=0.12.1->sktime) (0.5.1)

# %%
# Load
all_videos = pickle.load(open('all-squats.dump', 'rb'))

# %%
# Find the shortest and longest length video in terms of frame number
lengths = []

for video in all_videos:
    lengths.append(len(video[1]))
    
shortest_vid = min(lengths)
longest_vid = max(lengths)

# %%
# The list we want to convert has format: [{'frame': num, 'coordinates': {'x1'...'z33'}}]
def convert_list_to_df(list_to_convert):
    d = {'frame': []}
    for i in range(33):
        d['x' +  str(i)] = []
        d['y' +  str(i)] = []
        d['z' +  str(i)] = []
    
    for frame in list_to_convert:
        d['frame'].append(frame['frame'])
        for j in range(33):
            d['x' +  str(j)].append(frame['coordinates']['x' + str(j)])
            d['y' +  str(j)].append(frame['coordinates']['y' + str(j)])
            d['z' +  str(j)].append(frame['coordinates']['z' + str(j)])
    return d

# %%
import numpy as np
import math

# Get the angle between 3 keypoint's coordinates
# INPUT: frame (dict storing the xy of all the keypoints), the keypoint numbers
# OUTPUT: angle as float
def get_angle(frame, keypoint_1, keypoint_2, keypoint_3):
    a = np.array([frame['x'+str(keypoint_1)], frame['y'+str(keypoint_1)]])
    b = np.array([frame['x'+str(keypoint_2)], frame['y'+str(keypoint_2)]])
    c = np.array([frame['x'+str(keypoint_3)], frame['y'+str(keypoint_3)]])
    
    ba = a - b
    bc = c - b

    cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
    angle = math.degrees(np.arccos(cosine_angle))
    
    return angle

# %%
# Get the y differnece between two keypoints in a frame
# INPUT: frame (dictionary of keypoints to coordinates) and the 2 keypoints
# OUPUT: absolute value of the difference
def get_y_difference(frame, keypoint_1, keypoint_2):
    return abs(frame['y'+str(keypoint_1)] - frame['y'+str(keypoint_2)])

# %%
# Change a column in a DataFrame to a Series
# Also makes all the series generated from videos the same length
# INPUT: Column name and DataFrame we want to extract in form {frame number: value at that frame number}
# OUTPUT: Pandas Series of the dictionary formed
def df_column_to_series(name, df):
    out_dict = {}

    largest_frame = 0
    
    for i in range(longest_vid):
        # If the video is shorther than the largest video, fill the values in the series with 0.0
        if i >= len(df):
            largest_frame += 1
            out_dict[largest_frame] = 0.0 
        else:
            out_dict[int(df.iloc[i]['frame'])-1] = df.iloc[i][name]
            largest_frame = int(df.iloc[i]['frame'])-1
    
    return pd.Series(out_dict)

# %% [markdown]
# In order for sktime univariate classification to work, we need the series to be the same length, but we have videos of different lengths. To account for this we make all the series the same length by zero-padding the end of the series to match the longest length video (the video with the most frames).

# %%
# Change the shape from: number of frames x features to: 1 x features length for sktime
# INPUT: The DataFrame we want to convert
# OUTPUT: The new converted DataFrame
def df_reshape(df):
    data = {}

    for col in df.columns:
        data[col] = []

    for col in df.columns:
        data[col].append(df_column_to_series(col, df))

    data.pop('frame')
    return pd.DataFrame(data)

# %% [markdown]
# # 1. Setup Training & Testing Sets

# %%
# Form the testing and training sets
X = []
y = []

for i in all_videos:
    X.append(i[1])
    y.append(i[0])

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

y_train = pd.Series(y_train)

# %% [markdown]
# ![image4%20%281%29.jpg](attachment:image4%20%281%29.jpg)

# %%
# Get data in the right form for the classifiers
X_train_df = pd.DataFrame()

for vid in X_train:
    df = pd.DataFrame(convert_list_to_df(vid)) 
    
    # Extract the useful angles
    df['knee_hip_difference'] = df.apply(lambda row: get_y_difference(row, 23, 25), axis=1)
    df['hip_angle'] = df.apply(lambda row: get_angle(row, 11, 23, 25), axis=1)
    
    X_train_df = X_train_df.append(df_reshape(df))

# %%
X_train_df
# Out:
#                                                   x0  \
# 0  0      0.320190
# 1      0.320196
# 2      0.32022...
# 0  0      0.330098
# 1      0.330815
# 2      0.33084...
# 0  0      0.332971
# 1      0.334009
# 2      0.33307...
# 0  0      0.309604
# 1      0.315213
# 2      0.31401...
# 0  0      0.369023
# 1      0.364515
# 2      0.36058...
# 0  0      0.366803
# 1      0.342003
# 2      0.33514...
# 0  0      0.342834
# 1      0.344155
# 2      0.34458...
# 0  0      0.371532
# 1      0.368917
# 2      0.36655...
# 0  0      0.339257
# 1      0.339841
# 2      0.34000...
# 0  0      0.291180
# 1      0.294261
# 2      0.29423...
# 0  0      0.402346
# 1      0.400589
# 2      0.39705...
# 0  0      0.338350
# 1      0.346842
# 2      0.35074...
# 0  0      0.343167
# 1      0.343198
# 2      0.34315...
# 0  0      0.303718
# 1      0.292242
# 2      0.29219...
# 0  0      0.321475
# 1      0.335282
# 2      0.36303...
# 0  0      0.371688
# 1      0.371804
# 2      0.37167...
# 0  0      0.303472
# 1      0.303470
# 2      0.28484...
# 0  0      0.363173
# 1      0.361792
# 2      0.36166...
# 0  0      0.354146
# 1      0.340587
# 2      0.33603...
# 0  0      0.355587
# 1      0.356001
# 2      0.35506...
# 0  0      0.337947
# 1      0.337537
# 2      0.33739...
# 0  0      0.348372
# 1      0.349583
# 2      0.34982...
# 0  0      0.331109
# 1      0.334562
# 2      0.33493...
# 0  0      0.339386
# 1      0.336103
# 2      0.33614...
# 0  0      0.376147
# 1      0.372266
# 2      0.36817...
# 0  0      0.300214
# 1      0.299379
# 2      0.30123...
# 0  0      0.382860
# 1      0.380390
# 2      0.38401...
# 0  0      0.318689
# 1      0.320686
# 2      0.32280...
# 0  0      0.315815
# 1      0.315849
# 2      0.31235...
# 0  0      0.344094
# 1      0.366937
# 2      0.36615...
# 0  0      0.344346
# 1      0.344350
# 2      0.34434...
# 0  0      0.383860
# 1      0.389409
# 2      0.38965...
# 0  0      0.351967
# 1      0.353558
# 2      0.35369...
# 0  0      0.345570
# 1      0.343152
# 2      0.34107...
# 0  0      0.314418
# 1      0.172582
# 2      0.17280...
# 0  0      0.145159
# 1      0.145552
# 2      0.14733...
# 0  0      0.187611
# 1      0.188309
# 2      0.19161...
# 0  0      0.181566
# 1      0.182151
# 2      0.18351...
# 0  0      0.201068
# 1      0.201258
# 2      0.20123...
# 0  0      0.179657
# 1      0.179391
# 2      0.17846...
# 0  0      0.134222
# 1      0.143942
# 2      0.14444...
# 0  0      0.200851
# 1      0.200878
# 2      0.20088...
# 0  0      0.131428
# 1      0.130363
# 2      0.12877...
# 0  0      0.170280
# 1      0.173375
# 2      0.17330...
# 0  0      0.174983
# 1      0.171948
# 2      0.17153...
# 0  0      0.113846
# 1      0.110115
# 2      0.10571...
# 0  0      0.195141
# 1      0.195639
# 2      0.19649...
# 0  0      0.161940
# 1      0.162439
# 2      0.16257...
# 0  0      0.115213
# 1      0.119767
# 2      0.12021...
# 0  0      0.168623
# 1      0.168868
# 2      0.16886...
# 0  0      0.127181
# 1      0.126623
# 2      0.12697...
# 0  0      0.152607
# 1      0.152853
# 2      0.15568...
# 0  0      0.209489
# 1      0.206770
# 2      0.20556...
# 0  0      0.173340
# 1      0.173422
# 2      0.17327...
# 0  0      0.164427
# 1      0.164560
# 2      0.16420...
# 0  0      0.191802
# 1      0.181059
# 2      0.14521...
# 0  0      0.169699
# 1      0.168226
# 2      0.16761...
# 0  0      0.184616
# 1      0.183737
# 2      0.18572...
# 0  0      0.129453
# 1      0.136186
# 2      0.13562...
# 0  0      0.193621
# 1      0.192593
# 2      0.19160...
# 0  0      0.142986
# 1      0.144120
# 2      0.14352...
# 0  0      0.139858
# 1      0.142191
# 2      0.14248...
# 0  0      0.194821
# 1      0.192090
# 2      0.19209...
# 0  0      0.161901
# 1      0.164418
# 2      0.16443...
# 0  0      0.149922
# 1      0.148962
# 2      0.14888...
# 0  0      0.158504
# 1      0.162072
# 2      0.16199...
# 0  0      0.169491
# 1      0.169432
# 2      0.16943...
# 0  0      0.110178
# 1      0.117809
# 2      0.12425...
# 0  0      0.184079
# 1      0.195472
# 2      0.19996...
#
#                                                   z0  \
# 0  0     -0.071811
# 1     -0.081274
# 2     -0.07884...
# 0  0     -0.062994
# 1     -0.034599
# 2     -0.02753...
# 0  0     -0.048716
# 1     -0.038323
# 2     -0.03636...
# 0  0     -0.120018
# 1     -0.131731
# 2     -0.14196...
# 0  0     -0.271024
# 1     -0.167871
# 2     -0.09628...
# 0  0     -0.188847
# 1     -0.176920
# 2     -0.17526...
# 0  0     -0.159903
# 1     -0.145684
# 2     -0.14095...
# 0  0     -0.359018
# 1     -0.320353
# 2     -0.33463...
# 0  0     -0.037877
# 1     -0.038017
# 2     -0.03800...
# 0  0     -0.113658
# 1     -0.119052
# 2     -0.11931...
# 0  0     -0.247785
# 1     -0.260832
# 2     -0.24312...
# 0  0     -0.203052
# 1     -0.209365
# 2     -0.26658...
# 0  0     -0.066482
# 1     -0.078147
# 2     -0.06329...
# 0  0     -0.226854
# 1     -0.294698
# 2     -0.28892...
# 0  0     -0.106655
# 1     -0.084186
# 2     -0.08692...
# 0  0     -0.186514
# 1     -0.196112
# 2     -0.19335...
# 0  0     -0.179066
# 1     -0.191709
# 2     -0.33690...
# 0  0     -0.116207
# 1     -0.047179
# 2     -0.04139...
# 0  0     -0.146753
# 1     -0.303041
# 2     -0.30050...
# 0  0     -0.145919
# 1     -0.106746
# 2     -0.05737...
# 0  0     -0.045896
# 1     -0.077802
# 2     -0.08297...
# 0  0     -0.037662
# 1     -0.058068
# 2     -0.06933...
# 0  0     -0.019857
# 1     -0.018810
# 2     -0.02424...
# 0  0     -0.064026
# 1     -0.219217
# 2     -0.23601...
# 0  0     -0.209780
# 1     -0.166239
# 2     -0.15650...
# 0  0     -0.182152
# 1     -0.128875
# 2     -0.13062...
# 0  0     -0.170337
# 1     -0.217775
# 2     -0.31131...
# 0  0     -0.080079
# 1     -0.093087
# 2     -0.09226...
# 0  0     -0.162180
# 1     -0.130054
# 2     -0.10875...
# 0  0     -0.179399
# 1     -0.084284
# 2     -0.09999...
# 0  0     -0.140066
# 1     -0.143376
# 2     -0.15146...
# 0  0     -0.264688
# 1     -0.385665
# 2     -0.37275...
# 0  0     -0.102292
# 1     -0.053818
# 2     -0.06478...
# 0  0     -0.198210
# 1     -0.200230
# 2     -0.25477...
# 0  0     -0.152750
# 1     -0.162246
# 2     -0.18067...
# 0  0     -0.162319
# 1     -0.141895
# 2     -0.14079...
# 0  0     -0.303071
# 1     -0.269477
# 2     -0.25409...
# 0  0     -0.176205
# 1     -0.095683
# 2     -0.08197...
# 0  0     -0.148008
# 1     -0.151521
# 2     -0.15149...
# 0  0     -0.321160
# 1     -0.289836
# 2     -0.28830...
# 0  0     -0.039374
# 1     -0.047612
# 2     -0.04210...
# 0  0     -0.304728
# 1     -0.290122
# 2     -0.20994...
# 0  0     -0.192242
# 1     -0.242575
# 2     -0.25588...
# 0  0     -0.046882
# 1     -0.031832
# 2     -0.02709...
# 0  0     -0.146428
# 1     -0.147364
# 2     -0.14850...
# 0  0     -0.162402
# 1     -0.148897
# 2     -0.11978...
# 0  0      0.046967
# 1      0.004267
# 2     -0.11934...
# 0  0     -0.073101
# 1     -0.068563
# 2     -0.06344...
# 0  0     -0.127799
# 1     -0.093910
# 2     -0.06093...
# 0  0     -0.199322
# 1     -0.275187
# 2     -0.32938...
# 0  0     -0.030305
# 1     -0.028408
# 2     -0.02354...
# 0  0     -0.192643
# 1     -0.212502
# 2     -0.22039...
# 0  0     -0.235166
# 1     -0.241562
# 2     -0.24199...
# 0  0     -0.037698
# 1     -0.036782
# 2     -0.01446...
# 0  0     -0.157663
# 1     -0.175118
# 2     -0.17939...
# 0  0     -0.179880
# 1     -0.230304
# 2     -0.22764...
# 0  0     -0.279889
# 1     -0.340009
# 2     -0.33616...
# 0  0     -0.221941
# 1     -0.175166
# 2     -0.17100...
# 0  0     -0.163732
# 1     -0.151283
# 2     -0.16531...
# 0  0     -0.155863
# 1     -0.111711
# 2     -0.08857...
#
#                                                   x1  \
# 0  0      0.326377
# 1      0.327127
# 2      0.32762...
# 0  0      0.336792
# 2      0.19010...
# 0  0      0.154826
# 1      0.155964
# 2      0.15602...
# 0  0      0.144558
# 1      0.144573
# 2      0.14369...
# 0  0      0.172824
# 1      0.167361
# 2      0.13192...
# 0  0      0.152645
# 1      0.151973
# 2      0.15180...
# 0  0      0.164209
# 1      0.163624
# 2      0.16669...
# 0  0      0.112926
# 1      0.117741
# 2      0.11528...
# 0  0      0.177231
# 1      0.176767
# 2      0.17608...
# 0  0      0.122166
# 1      0.124058
# 2      0.12378...
# 0  0      0.120126
# 1      0.124160
# 2      0.12468...
# 0  0      0.178792
# 1      0.176673
# 2      0.17671...
# 0  0      0.144391
# 1      0.148295
# 2      0.14826...
# 0  0      0.130767
# 1      0.130410
# 2      0.13042...
# 0  0      0.138585
# 1      0.141804
# 2      0.14178...
# 0  0      0.150722
# 1      0.151590
# 2      0.15279...
# 0  0      0.091000
# 1      0.100360
# 2      0.10869...
# 0  0      0.166629
# 1      0.180159
# 2      0.18396...
#
#                                                   z1  \
# 0  0     -0.117479
# 1     -0.123403
# 2     -0.12185...
# 0  0     -0.107423
# 1     -0.071532
# 2     -0.06386...
# 0  0     -0.093279
# 1     -0.081029
# 2     -0.07817...
# 0  0     -0.175584
# 1     -0.188561
# 2     -0.19881...
# 0  0     -0.327196
# 1     -0.221007
# 2     -0.15429...
# 0  0     -0.248998
# 1     -0.247197
# 2     -0.24729...
# 0  0     -0.212734
# 1     -0.195231
# 2     -0.18966...
# 0  0     -0.430493
# 1     -0.381979
# 2     -0.38305...
# 0  0     -0.082142
# 1     -0.080563
# 2     -0.07975...
# 0  0     -0.176918
# 1     -0.182416
# 2     -0.18239...
# 0  0     -0.269376
# 1     -0.272797
# 2     -0.25726...
# 0  0     -0.277746
# 1     -0.285099
# 2     -0.33948...
# 0  0     -0.110451
# 1     -0.120191
# 2     -0.10470...
# 0  0     -0.296623
# 1     -0.370194
# 2     -0.36325...
# 0  0     -0.162187
# 1     -0.141104
# 2     -0.14317...
# 0  0     -0.256723
# 1     -0.268400
# 2     -0.26823...
# 0  0     -0.250057
# 1     -0.263966
# 2     -0.41141...
# 0  0     -0.161621
# 1     -0.095586
# 2     -0.08971...
# 0  0     -0.210680
# 1     -0.380615
# 2     -0.37749...
# 0  0     -0.201985
# 1     -0.162550
# 2     -0.10984...
# 0  0     -0.090233
# 1     -0.117883
# 2     -0.11766...
# 0  0     -0.081134
# 1     -0.098932
# 2     -0.11028...
# 0  0     -0.067614
# 1     -0.063289
# 2     -0.06490...
# 0  0     -0.138684
# 1     -0.293728
# 2     -0.30630...
# 0  0     -0.268375
# 1     -0.220319
# 2     -0.21010...
# 0  0     -0.247551
# 1     -0.196564
# 2     -0.19546...
# 0  0     -0.244486
# 1     -0.284060
# 2     -0.36839...
# 0  0     -0.136307
# 1     -0.151184
# 2     -0.15021...
# 0  0     -0.225975
# 1     -0.193061
# 2     -0.16847...
# 0  0     -0.232260
# 1     -0.138682
# 2     -0.15589...
# 0  0     -0.188603
# 1     -0.194989
# 2     -0.20570...
# 0  0     -0.333149
# 1     -0.446670
# 2     -0.43373...
# 0  0     -0.144871
# 1     -0.096217
# 2     -0.10812...
# 0  0     -0.270897
# 1     -0.278188
# 2     -0.33523...
# 0  0     -0.221766
# 1     -0.231119
# 2     -0.24109...
# 0  0     -0.220962
# 1     -0.204798
# 2     -0.20135...
# 0  0     -0.360219
# 1     -0.333366
# 2     -0.31455...
# 0  0     -0.229566
# 1     -0.150069
# 2     -0.13550...
# 0  0     -0.212272
# 1     -0.222097
# 2     -0.22258...
# 0  0     -0.382538
# 1     -0.346791
# 2     -0.34462...
# 0  0     -0.082520
# 1     -0.088949
# 2     -0.08208...
# 0  0     -0.373887
# 1     -0.357090
# 2     -0.27642...
# 0  0     -0.254207
# 1     -0.307277
# 2     -0.32017...
# 0  0     -0.091048
# 1     -0.073433
# 2     -0.06977...
# 0  0     -0.212069
# 1     -0.212435
# 2     -0.21236...
# 0  0     -0.215804
# 1     -0.198832
# 2     -0.17037...
# 0  0     -0.002588
# 1     -0.039172
# 2     -0.15241...
# 0  0     -0.116665
# 1     -0.110783
# 2     -0.10711...
# 0  0     -0.181314
# 1     -0.148333
# 2     -0.11329...
# 0  0     -0.272712
# 1     -0.347874
# 2     -0.40215...
# 0  0     -0.074198
# 1     -0.074072
# 2     -0.07105...
# 0  0     -0.264974
# 1     -0.288386
# 2     -0.29668...
# 0  0     -0.290508
# 1     -0.300077
# 2     -0.30015...
# 0  0     -0.080439
# 1     -0.080384
# 2     -0.05818...
# 0  0     -0.225839
# 1     -0.234910
# 2     -0.23934...
# 0  0     -0.245561
# 1     -0.300679
# 2     -0.29884...
# 0  0     -0.353404
# 1     -0.402202
# 2     -0.38632...
# 0  0     -0.281758
# 1     -0.239347
# 2     -0.23854...
# 0  0     -0.227798
# 1     -0.220751
# 2     -0.23582...
# 0  0     -0.210568
# 1     -0.173403
# 2     -0.14519...
#
#                                                   x2  \
# 0  0      0.331129
# 1      0.332513
# 2      0.33321...
# 0  0      0.341419
# 1      0.344054
# 2      0.34446...
# 0  0      0.345488
# 1      0.349063
# 2      0.34898...
# 0  0      0.322305
# 1      0.332222
# 2      0.33170...
# 0  0      0.387674
# 1      0.384054
# 2      0.37864...
# 0  0      0.379450
# 1      0.356925
# 2      0.34954...
# 0  0      0.358233
# 1      0.363231
# 2      0.36439...
# 0  0      0.390053
# 1      0.389202
# 2      0.38853...
# 0  0      0.350670
# 1      0.355315
# 2      0.35706...
# 0  0      0.296521
# 1      0.302031
# 2      0.30192...
# 0  0      0.428971
# 1      0.428383
# 2      0.42531...
# 0  0      0.356197
# 1      0.366286
# 2      0.37146...
# 0  0      0.354222
# 1      0.358005
# 2      0.35819...
# 0  0      0.317612
# 1      0.307802
# 2      0.30684...
# 0  0      0.334455
# 1      0.351118
# 2      0.38556...
# 0  0      0.387305
# 1      0.387716
# 2      0.38754...
# 0  0      0.316521
# 1      0.316618
# 2      0.29969...
# 0  0      0.370648
# 1      0.370099
# 2      0.37009...
# 0  0      0.367865
# 1      0.353835
# 2      0.34965...
# 0  0      0.363130
# 1      0.364604
# 1     -0.071578
# 2     -0.06390...
# 0  0     -0.093317
# 1     -0.081074
# 2     -0.07822...
# 0  0     -0.175623
# 1     -0.188605
# 2     -0.19884...
# 0  0     -0.327242
# 1     -0.221041
# 2     -0.15430...
# 0  0     -0.248954
# 1     -0.247161
# 2     -0.24726...
# 0  0     -0.212770
# 1     -0.195265
# 2     -0.18971...
# 0  0     -0.430559
# 1     -0.381988
# 2     -0.38331...
# 0  0     -0.082187
# 1     -0.080596
# 2     -0.07977...
# 0  0     -0.176937
# 1     -0.182413
# 2     -0.18239...
# 0  0     -0.269442
# 1     -0.272868
# 2     -0.25735...
# 0  0     -0.277797
# 1     -0.285081
# 2     -0.33938...
# 0  0     -0.110512
# 1     -0.120251
# 2     -0.10475...
# 0  0     -0.296687
# 1     -0.370088
# 2     -0.36314...
# 0  0     -0.162276
# 1     -0.141165
# 2     -0.14325...
# 0  0     -0.256799
# 1     -0.268358
# 2     -0.26819...
# 0  0     -0.250049
# 1     -0.263975
# 2     -0.41140...
# 0  0     -0.161665
# 1     -0.095619
# 2     -0.08974...
# 0  0     -0.210629
# 1     -0.380571
# 2     -0.37743...
# 0  0     -0.202107
# 1     -0.162567
# 2     -0.10983...
# 0  0     -0.090289
# 1     -0.117933
# 2     -0.11770...
# 0  0     -0.081174
# 1     -0.098966
# 2     -0.11031...
# 0  0     -0.067663
# 1     -0.063316
# 2     -0.06491...
# 0  0     -0.138679
# 1     -0.293757
# 2     -0.30631...
# 0  0     -0.268442
# 1     -0.220332
# 2     -0.21008...
# 0  0     -0.247502
# 1     -0.196592
# 2     -0.19549...
# 0  0     -0.244578
# 1     -0.283997
# 2     -0.36835...
# 0  0     -0.136338
# 1     -0.151199
# 2     -0.15022...
# 0  0     -0.226063
# 1     -0.193083
# 2     -0.16842...
# 0  0     -0.232295
# 1     -0.138699
# 2     -0.15592...
# 0  0     -0.188582
# 1     -0.194955
# 2     -0.20565...
# 0  0     -0.333202
# 1     -0.446669
# 2     -0.43377...
# 0  0     -0.144919
# 1     -0.096245
# 2     -0.10816...
# 0  0     -0.271009
# 1     -0.278260
# 2     -0.33524...
# 0  0     -0.221701
# 1     -0.231109
# 2     -0.24109...
# 0  0     -0.221062
# 1     -0.204846
# 2     -0.20138...
# 0  0     -0.360166
# 1     -0.333341
# 2     -0.31449...
# 0  0     -0.229596
# 1     -0.150039
# 2     -0.13550...
# 0  0     -0.212224
# 1     -0.222119
# 2     -0.22261...
# 0  0     -0.382613
# 1     -0.346751
# 2     -0.34459...
# 0  0     -0.082581
# 1     -0.089014
# 2     -0.08215...
# 0  0     -0.373902
# 1     -0.357038
# 2     -0.27637...
# 0  0     -0.254315
# 1     -0.307309
# 2     -0.32021...
# 0  0     -0.091094
# 1     -0.073474
# 2     -0.06980...
# 0  0     -0.212036
# 1     -0.212396
# 2     -0.21232...
# 0  0     -0.215791
# 1     -0.198842
# 2     -0.17039...
# 0  0     -0.002667
# 1     -0.039220
# 2     -0.15256...
# 0  0     -0.116736
# 1     -0.110831
# 2     -0.10714...
# 0  0     -0.181335
# 1     -0.148370
# 2     -0.11333...
# 0  0     -0.272720
# 1     -0.347854
# 2     -0.40218...
# 0  0     -0.074236
# 1     -0.074105
# 2     -0.07107...
# 0  0     -0.264983
# 1     -0.288398
# 2     -0.29672...
# 0  0     -0.290628
# 1     -0.300061
# 2     -0.30013...
# 0  0     -0.080499
# 1     -0.080442
# 2     -0.05822...
# 0  0     -0.225826
# 1     -0.234850
# 2     -0.23925...
# 0  0     -0.245575
# 1     -0.300621
# 2     -0.29882...
# 0  0     -0.353471
# 1     -0.402209
# 2     -0.38623...
# 0  0     -0.281689
# 1     -0.239353
# 2     -0.23856...
# 0  0     -0.227845
# 1     -0.220770
# 2     -0.23584...
# 0  0     -0.210529
# 1     -0.173391
# 2     -0.14522...
#
#                                                   x3  ...  \
# 0  0      0.335953
# 1      0.338205
# 2      0.33928...  ...
# 0  0      0.345848
# 1      0.349310
# 2      0.34957...  ...
# 0  0      0.350536
# 1      0.354669
# 2      0.35457...  ...
# 0  0      0.328804
# 1      0.338778
# 2      0.33821...  ...
# 0  0      0.395460
# 1      0.391298
# 2      0.38572...  ...
# 0  0      0.385154
# 1      0.360531
# 2      0.35252...  ...
# 0  0      0.365592
# 1      0.371575
# 2      0.37293...  ...
# 0  0      0.395454
# 1      0.395089
# 2      0.39476...  ...
# 0  0      0.355664
# 1      0.361055
# 2      0.36324...  ...
# 0  0      0.300732
# 1      0.306220
# 2      0.30589...  ...
# 0  0      0.437193
# 1      0.436956
# 2      0.43400...  ...
# 0  0      0.360059
# 1      0.369829
# 2      0.37505...  ...
# 0  0      0.360638
# 1      0.364982
# 2      0.36528...  ...
# 0  0      0.321045
# 1      0.311439
# 2      0.31002...  ...
# 0  0      0.338488
# 1      0.355056
# 2      0.39003...  ...
# 0  0      0.392190
# 1      0.392416
# 2      0.39179...  ...
# 0  0      0.320839
# 1      0.320908
# 2      0.30374...  ...
# 0  0      0.374792
# 1      0.374343
# 2      0.37434...  ...
# 0  0      0.374105
# 1      0.357395
# 2      0.35279...  ...
# 0  0      0.368345
# 1      0.370537
# 2      0.36974...  ...
# 0  0      0.353666
# 1      0.354878
# 2      0.35627...  ...
# 0  0      0.365021
# 1      0.369271
# 2      0.37048...  ...
# 0  0      0.346527
# 1      0.350141
# 2      0.35165...  ...
# 0  0      0.348350
# 1      0.348390
# 2      0.35000...  ...
# 0  0      0.397598
# 1      0.393718
# 2      0.39017...  ...
# 0  0      0.310530
# 1      0.309797
# 2      0.31241...  ...
# 0  0      0.408327
# 1      0.408391
# 2      0.41757...  ...
# 0  0      0.337261
# 1      0.339882
# 2      0.34299...  ...
# 0  0      0.330555
# 1      0.336351
# 2      0.33557...  ...
# 0  0      0.361935
# 1      0.382405
# 2      0.38496...  ...
# 0  0      0.363431
# 1      0.365012
# 2      0.36647...  ...
# 0  0      0.412771
# 1      0.426780
# 2      0.42755...  ...
# 0  0      0.369995
# 1      0.374044
# 2      0.37472...  ...
# 0  0      0.362395
# 1      0.361847
# 2      0.36190...  ...
# 0  0      0.326990
# 1      0.327050
# 2      0.32708...  ...
# 0  0      0.347628
# 1      0.366866
# 2      0.38075...  ...
# 0  0      0.424708
# 1      0.418013
# 2      0.40475...  ...
# 0  0      0.360602
# 1      0.372768
# 2      0.38035...  ...
# 0  0      0.327783
# 1      0.327841
# 2      0.32785...  ...
# 0  0      0.405018
# 1      0.414249
# 2      0.41641...  ...
# 0  0      0.405282
# 1      0.411105
# 2      0.41171...  ...
# 0  0      0.394114
# 1      0.395763
# 2      0.39648...  ...
# 0  0      0.466318
# 1      0.466316
# 2      0.46369...  ...
# 0  0      0.361925
# 1      0.365928
# 2      0.36811...  ...
# 0  0      0.330765
# 1      0.330883
# 2      0.33284...  ...
# 0  0      0.392393
# 1      0.398968
# 2      0.39886...  ...
# 0  0      0.395659
# 1      0.419190
# 2      0.43118...  ...
# 0  0      0.415147
# 1      0.415888
# 2      0.41795...  ...
# 0  0      0.345031
# 1      0.372654
# 2      0.38903...  ...
# 0  0      0.324433
# 1      0.323677
# 2      0.32490...  ...
# 0  0      0.378471
# 1      0.379346
# 2      0.38046...  ...
# 0  0      0.326722
# 1      0.326861
# 2      0.32568...  ...
# 0  0      0.400561
# 1      0.427623
# 2      0.42696...  ...
# 0  0      0.370380
# 1      0.373318
# 2      0.37592...  ...
# 0  0      0.306834
# 1      0.307528
# 2      0.30736...  ...
# 0  0      0.361654
# 1      0.355122
# 2      0.35435...  ...
# 0  0      0.448848
# 1      0.467158
# 2      0.46699...  ...
# 0  0      0.332643
# 1      0.328507
# 2      0.32565...  ...
# 0  0      0.380265
# 1      0.374662
# 2      0.36965...  ...
# 0  0      0.357035
# 1      0.376252
# 2      0.38450...  ...
#
#                                                  y30  \
# 0  0      0.722284
# 1      0.735019
# 2      0.74262...
# 0  0      0.761698
# 1      0.767748
# 2      0.76742...
# 0  0      0.761652
# 1      0.764740
# 2      0.76521...
# 0  0      0.765551
# 1      0.770045
# 2      0.77297...
# 0  0      0.754707
# 1      0.766600
# 2      0.78555...
# 0  0      0.782124
# 1      0.788746
# 2      0.79028...
# 0  0      0.757613
# 1      0.776736
# 2      0.77521...
# 0  0      0.750572
# 1      0.750537
# 2      0.74984...
# 0  0      0.761049
# 1      0.761568
# 2      0.77177...
# 0  0      0.767293
# 1      0.766651
# 2      0.76601...
# 0  0      0.650925
# 1      0.648438
# 2      0.64755...
# 0  0      0.790102
# 1      0.781711
# 2      0.78178...
# 0  0      0.725308
# 1      0.729765
# 2      0.73064...
# 0  0      0.779290
# 1      0.762665
# 2      0.75780...
# 0  0      0.766070
# 1      0.766994
# 2      0.76698...
# 0  0      0.783569
# 1      0.786694
# 2      0.78666...
# 0  0      0.771816
# 1      0.772168
# 2      0.77226...
# 0  0      0.698518
# 1      0.715481
# 2      0.71917...
# 0  0      0.808490
# 1      0.800833
# 2      0.79641...
# 0  0      0.749969
# 1      0.766816
# 2      0.77559...
# 0  0      0.714064
# 1      0.713850
# 2      0.71532...
# 0  0      0.740182
# 1      0.750487
# 2      0.75079...
# 0  0      0.752551
# 1      0.760719
# 2      0.76067...
# 1      177.049351
# 2      177...
# 0  0      176.462819
# 1      178.843002
# 2      176...
# 0  0      179.791550
# 1      178.824875
# 2      178...
# 0  0      177.457879
# 1      172.957651
# 2      172...
# 0  0      177.446664
# 1      175.469153
# 2      172...
# 0  0      179.629120
# 1      178.165183
# 2      177...
# 0  0      175.399937
# 1      173.828275
# 2      173...
# 0  0      172.953158
# 1      174.709848
# 2      175...
# 0  0      175.572534
# 1      178.845235
# 2      179...
# 0  0      176.302287
# 1      177.005284
# 2      176...
# 0  0      179.621113
# 1      177.043437
# 2      175...
# 0  0      179.390818
# 1      178.206835
# 2      177...
# 0  0      178.045502
# 1      175.605997
# 2      173...
# 0  0      178.388689
# 1      178.479697
# 2      178...
# 0  0      178.118493
# 1      174.356033
# 2      172...
# 0  0      162.624470
# 1      169.281729
# 2      172...
# 0  0      177.205895
# 1      177.856829
# 2      177...
# 0  0      179.858641
# 1      175.030654
# 2      174...
# 0  0      168.640518
# 1      173.925507
# 2      176...
# 0  0      175.311906
# 1      175.095938
# 2      174...
# 0  0      178.412433
# 1      176.045667
# 2      175...
# 0  0      175.999915
# 1      172.842021
# 2      171...
# 0  0      173.314173
# 1      176.838759
# 2      179...
# 0  0      177.849682
# 1      174.386330
# 2      172...
# 0  0      179.902078
# 1      176.511867
# 2      177...
# 0  0      171.885389
# 1      174.239462
# 2      175...
# 0  0      174.128138
# 1      178.445087
# 2      178...
# 0  0      179.412428
# 1      178.584263
# 2      177...
# 0  0      167.029258
# 1      170.695962
# 2      172...
# 0  0      175.234301
# 1      174.763267
# 2      174...
# 0  0      177.385007
# 1      176.172390
# 2      175...
# 0  0      176.219371
# 1      173.303425
# 2      171...
# 0  0      175.407749
# 1      175.518850
# 2      175...
# 0  0      158.894562
# 1      158.899310
# 2      154...
# 0  0      174.769003
# 1      172.437157
# 2      169...
#
# [60 rows x 101 columns]

# %%
print("X_train_df's shape: " + str(X_train_df.shape) + '\n' + "y_train's length: " + str(len(y_train)))
# Out:
# X_train_df's shape: (60, 101)
# y_train's length: 60

# %%
# Fix the index so that they don't all have value of 0
X_train_df = X_train_df.reset_index(drop=True)

# %%
# Drop all other columns apart from the specific
X_train_df_1 = X_train_df.drop(X_train_df.columns.difference(['knee_hip_difference']), 1) 
X_train_df_2 = X_train_df.drop(X_train_df.columns.difference(['hip_angle']), 1)

# %%
# Prepare the testing set same as the training set
X_test_df = pd.DataFrame()

for vid in X_test:
    df = pd.DataFrame(convert_list_to_df(vid))
    df['knee_hip_difference'] = df.apply(lambda row: get_y_difference(row, 23, 25), axis=1)
    df['hip_angle'] = df.apply(lambda row: get_angle(row, 11, 23, 27), axis=1)
    X_test_df = X_test_df.append(df_reshape(df))

# %%
X_test_df_1 = X_test_df.drop(X_test_df.columns.difference(['knee_hip_difference']), 1) 
X_test_df_2 = X_test_df.drop(X_test_df.columns.difference(['hip_angle']), 1)

# %%
print("X_test_df's shape: " + str(X_test_df.shape) + '\n' + "y_test's length: " + str(len(y_test)))
# Out:
# X_test_df's shape: (30, 101)
# y_test's length: 30

# %% [markdown]
# # 2. Train & Evaluate Models

# %%
labels = ['parallel', 'leaning', 'good']

# List to keep track of metrics for each
knee_hip_scores = [] # Knee-hip difference (23, 25) - keypoint numbers, see above for reference
hip_scores = [] # Hip angle (11, 23, 25)

def evaluate_model(model_name, prediction, display_matrix=False):
    acc = metrics.accuracy_score(y_test, prediction)
    f1 = f1_score(y_test, prediction, average='micro')
    precision = precision_score(y_test, prediction, average='macro')
    recall = recall_score(y_test, prediction, average='macro')

    model_metrics = {'Classifier': model_name, 
                   'Accuracy': acc, 
                   'Precision': precision, 
                   'Recall': recall,
                   'F1 Score': f1}

    if display_matrix:
        cm = confusion_matrix(y_test, prediction, labels=labels)
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
        disp.plot()
        plt.title(model_name)
        plt.show()

    return model_metrics

# %% [markdown]
# ## Using Knee-Hip y-difference Distance (23, 25)

# %% [markdown]
# ### Distance-based

# %% [markdown]
# #### KNeighbours Time Series

# %%
clf = KNeighborsTimeSeriesClassifier()
clf.fit(X_train_df_1, y_train)
y_pred = clf.predict(X_test_df_1)

scores = evaluate_model('KNeighbours', y_pred, True)
knee_hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'KNeighbours', 'Accuracy': 0.9666666666666667, 'Precision': 0.9722222222222222, 'Recall': 0.9629629629629629, 'F1 Score': 0.9666666666666667}

# %% [markdown]
# #### Elastic Ensemble

# %%
clf = ElasticEnsemble(
    proportion_of_param_options=0.1,
    proportion_train_for_test=0.1,
    distance_measures = ["dtw","ddtw"],
    majority_vote=True,
    random_state=1
)
clf.fit(X_train_df_1, y_train)
y_pred = clf.predict(X_test_df_1)

scores = evaluate_model('Elastic', y_pred, True)
knee_hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'Elastic', 'Accuracy': 0.9333333333333333, 'Precision': 0.9487179487179488, 'Recall': 0.9259259259259259, 'F1 Score': 0.9333333333333333}

# %% [markdown]
# #### Proximity Forest

# %%
clf = ProximityForest(n_estimators=5, random_state=1)
clf.fit(X_train_df_1, pd.Series(y_train))
y_pred = clf.predict(X_test_df_1)

scores = evaluate_model('Proximity Forest', y_pred)
knee_hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'Proximity Forest', 'Accuracy': 0.7666666666666667, 'Precision': 0.7884615384615384, 'Recall': 0.7781144781144781, 'F1 Score': 0.7666666666666667}

# %% [markdown]
# ### Dictionary-based

# %% [markdown]
# #### IndividualBOSS

# %%
clf = IndividualBOSS()
clf.fit(X_train_df_1, y_train)
y_pred = clf.predict(X_test_df_1)

scores = evaluate_model('IndividualBOSS', y_pred)
knee_hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'IndividualBOSS', 'Accuracy': 0.6333333333333333, 'Precision': 0.6962962962962963, 'Recall': 0.6276094276094276, 'F1 Score': 0.6333333333333333}

# %% [markdown]
# #### BOSSEnsemble

# %%
clf = BOSSEnsemble(max_ensemble_size=5, random_state=1)
clf.fit(X_train_df_1, y_train)
y_pred = clf.predict(X_test_df_1)

scores = evaluate_model('BOSSEnsemble', y_pred)
knee_hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'BOSSEnsemble', 'Accuracy': 0.7666666666666667, 'Precision': 0.8148148148148149, 'Recall': 0.7622895622895624, 'F1 Score': 0.7666666666666667}

# %% [markdown]
# #### WEASEL

# %%
clf = WEASEL(window_inc=10, random_state=1)
clf.fit(X_train_df_1, y_train)
y_pred = clf.predict(X_test_df_1)

scores = evaluate_model('WEASEL', y_pred)
knee_hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'WEASEL', 'Accuracy': 0.9666666666666667, 'Precision': 0.9666666666666667, 'Recall': 0.9696969696969697, 'F1 Score': 0.9666666666666667}

# %% [markdown]
# ### Interval-based

# %% [markdown]
# #### Time Series Forest

# %%
# Train classifier
clf = TimeSeriesForestClassifier(random_state=1)
clf.fit(X_train_df_1, y_train)
y_pred = clf.predict(X_test_df_1)

scores = evaluate_model('Forest', y_pred)
knee_hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'Forest', 'Accuracy': 0.7333333333333333, 'Precision': 0.7999999999999999, 'Recall': 0.7356902356902357, 'F1 Score': 0.7333333333333333}

# %% [markdown]
# ### Kernel-based

# %%
clf = Arsenal(num_kernels=200, n_estimators=5, random_state=1)
clf.fit(X_train_df_1, y_train)
y_pred = clf.predict(X_test_df_1)

scores = evaluate_model('Arsenal', y_pred)
knee_hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'Arsenal', 'Accuracy': 0.9666666666666667, 'Precision': 0.9666666666666667, 'Recall': 0.9696969696969697, 'F1 Score': 0.9666666666666667}

# %% [markdown]
# ### Shapelet-based

# %%
clf = ShapeletTransformClassifier(
    estimator=RotationForest(n_estimators=3),
    n_shapelet_samples=500,
    max_shapelets=20,
    batch_size=100,
    random_state=1
)
clf.fit(X_train_df_1, y_train)
y_pred = clf.predict(X_test_df_1)

scores = evaluate_model('Shapelet', y_pred)
knee_hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'Shapelet', 'Accuracy': 0.7, 'Precision': 0.7241758241758242, 'Recall': 0.7016835016835018, 'F1 Score': 0.7}

# %% [markdown]
# ### Hybrid

# %%
clf = HIVECOTEV1(
    stc_params={
        "estimator": RotationForest(n_estimators=3),
        "n_shapelet_samples": 500,
        "max_shapelets": 20,
        "batch_size": 100,
    },
    tsf_params={"n_estimators": 10},
    rise_params={"n_estimators": 10},
    cboss_params={"n_parameter_samples": 25, "max_ensemble_size": 5},
    random_state=1
)
clf.fit(X_train_df_1, y_train)
y_pred = clf.predict(X_test_df_1)

scores = evaluate_model('HIVECOTEV1', y_pred, True)
knee_hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'HIVECOTEV1', 'Accuracy': 0.8, 'Precision': 0.8368298368298368, 'Recall': 0.8060606060606061, 'F1 Score': 0.8000000000000002}

# %% [markdown]
# ## Using Hip Angle (11, 23, 25)

# %% [markdown]
# ### Distance-based

# %% [markdown]
# #### KNeighbours Time Series

# %%
clf = KNeighborsTimeSeriesClassifier()
clf.fit(X_train_df_2, y_train)
y_pred = clf.predict(X_test_df_2)

scores = evaluate_model('KNeighbours', y_pred)
hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'KNeighbours', 'Accuracy': 0.3333333333333333, 'Precision': 0.11904761904761905, 'Recall': 0.3333333333333333, 'F1 Score': 0.3333333333333333}
# C:\Users\abid5.000\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# #### Elastic Ensemble

# %%
clf = ElasticEnsemble(
    proportion_of_param_options=0.1,
    proportion_train_for_test=0.1,
    distance_measures = ["dtw","ddtw"],
    majority_vote=True,
    random_state=1
)
clf.fit(X_train_df_2, y_train)
y_pred = clf.predict(X_test_df_2)

scores = evaluate_model('Elastic', y_pred)
hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'Elastic', 'Accuracy': 0.7, 'Precision': 0.8101851851851851, 'Recall': 0.6845117845117844, 'F1 Score': 0.7}

# %% [markdown]
# ### Dictionary-based

# %% [markdown]
# #### BOSSEnsemble

# %%
clf = BOSSEnsemble(max_ensemble_size=5, random_state=1)
clf.fit(X_train_df_2, y_train)
y_pred = clf.predict(X_test_df_2)

scores = evaluate_model('BOSSEnsemble', y_pred)
hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'BOSSEnsemble', 'Accuracy': 0.5666666666666667, 'Precision': 0.6984126984126985, 'Recall': 0.5521885521885522, 'F1 Score': 0.5666666666666667}

# %% [markdown]
# #### WEASEL

# %%
clf = WEASEL(window_inc=3, random_state=1)
clf.fit(X_train_df_2, y_train)
y_pred = clf.predict(X_test_df_2)

scores = evaluate_model('WEASEL', y_pred, True)
hip_scores.append(scores)
print(scores)
# Out:
# C:\Users\abid5.000\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'Classifier': 'WEASEL', 'Accuracy': 0.6, 'Precision': 0.4166666666666667, 'Recall': 0.5727272727272728, 'F1 Score': 0.6}

# %% [markdown]
# ### Interval-based

# %% [markdown]
# #### Time Series Forest

# %%
clf = TimeSeriesForestClassifier(random_state=1)
clf.fit(X_train_df_2, y_train)
y_pred = clf.predict(X_test_df_2)

scores = evaluate_model('Forest', y_pred)
hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'Forest', 'Accuracy': 0.6, 'Precision': 0.4166666666666667, 'Recall': 0.5727272727272728, 'F1 Score': 0.6}
# C:\Users\abid5.000\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Kernel-based

# %%
clf = Arsenal(num_kernels=200, n_estimators=5, random_state=1)
clf.fit(X_train_df_2, y_train)
y_pred = clf.predict(X_test_df_2)

scores = evaluate_model('Arsenal', y_pred, True)
hip_scores.append(scores)
print(scores)
# Out:
# C:\Users\abid5.000\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'Classifier': 'Arsenal', 'Accuracy': 0.6333333333333333, 'Precision': 0.43288084464555054, 'Recall': 0.6060606060606061, 'F1 Score': 0.6333333333333333}

# %% [markdown]
# ### Shapelet-based

# %%
clf = ShapeletTransformClassifier(
    estimator=RotationForest(n_estimators=3),
    n_shapelet_samples=500,
    max_shapelets=20,
    batch_size=100,
    random_state=1
)
clf.fit(X_train_df_2, y_train)
y_pred = clf.predict(X_test_df_2)

scores = evaluate_model('Shapelet', y_pred)
hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'Shapelet', 'Accuracy': 0.6333333333333333, 'Precision': 0.712121212121212, 'Recall': 0.6306397306397307, 'F1 Score': 0.6333333333333333}

# %% [markdown]
# ### Hybrid

# %%
clf = HIVECOTEV1(
    stc_params={
        "estimator": RotationForest(n_estimators=3),
        "n_shapelet_samples": 500,
        "max_shapelets": 20,
        "batch_size": 100,
    },
    tsf_params={"n_estimators": 10},
    rise_params={"n_estimators": 10},
    cboss_params={"n_parameter_samples": 25, "max_ensemble_size": 5},
    random_state=1
)
clf.fit(X_train_df_2, y_train)
y_pred = clf.predict(X_test_df_2)

scores = evaluate_model('HIVECOTEV1', y_pred)
hip_scores.append(scores)
print(scores)
# Out:
# {'Classifier': 'HIVECOTEV1', 'Accuracy': 0.5666666666666667, 'Precision': 0.7124183006535948, 'Recall': 0.5461279461279461, 'F1 Score': 0.5666666666666667}

# %% [markdown]
# # 3. Choose Best Model

# %% [markdown]
# ## Best Classifier for Knee-Hip Difference

# %%
knee_hip_scores_df = pd.DataFrame(knee_hip_scores)
knee_hip_scores_df = knee_hip_scores_df.sort_values(by = ['F1 Score'], ascending = False)
knee_hip_scores_df
# Out:
#          Classifier  Accuracy  Precision    Recall  F1 Score
# 0       KNeighbours  0.966667   0.972222  0.962963  0.966667
# 5            WEASEL  0.966667   0.966667  0.969697  0.966667
# 7           Arsenal  0.966667   0.966667  0.969697  0.966667
# 1           Elastic  0.933333   0.948718  0.925926  0.933333
# 9        HIVECOTEV1  0.800000   0.836830  0.806061  0.800000
# 2  Proximity Forest  0.766667   0.788462  0.778114  0.766667
# 4      BOSSEnsemble  0.766667   0.814815  0.762290  0.766667
# 6            Forest  0.733333   0.800000  0.735690  0.733333
# 8          Shapelet  0.700000   0.724176  0.701684  0.700000
# 3    IndividualBOSS  0.633333   0.696296  0.627609  0.633333

# %%
knee_hip_scores_df.plot.bar(x = 'Classifier', figsize = (18,5))
plt.title('Comparison of Classifiers for Knee-Hip Difference')
plt.show()

# %% [markdown]
# The perfect F1 score is generated by just looking at th knee-hip difference.

# %% [markdown]
# ## Best Classifier for Hip Angle

# %%
hip_scores_df = pd.DataFrame(hip_scores)
hip_scores_df = hip_scores_df.sort_values(by = ['F1 Score'], ascending = False)
hip_scores_df
# Out:
#      Classifier  Accuracy  Precision    Recall  F1 Score
# 1       Elastic  0.700000   0.810185  0.684512  0.700000
# 5       Arsenal  0.633333   0.432881  0.606061  0.633333
# 6      Shapelet  0.633333   0.712121  0.630640  0.633333
# 3        WEASEL  0.600000   0.416667  0.572727  0.600000
# 4        Forest  0.600000   0.416667  0.572727  0.600000
# 2  BOSSEnsemble  0.566667   0.698413  0.552189  0.566667
# 7    HIVECOTEV1  0.566667   0.712418  0.546128  0.566667
# 0   KNeighbours  0.333333   0.119048  0.333333  0.333333

# %%
hip_scores_df.plot.bar(x = 'Classifier', figsize = (18,5))
plt.title('Comparison of Classifiers for Hip Angle')
plt.show()

# %% [markdown]
# The classifiers struggle by just looking at the hip angle.
